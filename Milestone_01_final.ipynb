# %% [markdown]
# # Project Milestone One: Gathering your Team, Understanding the Problem,  Exploring the Data
#
# #### Due: Midnight on July 20th (with 2-hour grace period)
#
# #### There will be no late period on this homework, as we need to start manual grading immediately!
#
#
#
# ### What We Will Do in This Milestone Assignment
#
# 1. You will convene your team and fill out the Team Contract (in the Homework Repo), to be submitted to Gradescope.
# 2. You must select a team leader for the purpose of submitting this notebook, after the team collaborates to complete the assignment. This <a href=https://guides.gradescope.com/hc/en-us/articles/21863861823373-Adding-Group-Members-to-a-Submission>link</a> describes how to add group members to your leader's submission.
# 3. At the conclusion of your work on this Milestone, you will complete an Individual Evaluation of your team's work (in the Homework Repo) and upload it *individually* to Gradescope.
# 4. We will follow a simplified version of the **Machine Learning Project Checklist** in Appendix A in our textbook *Hands-On Machine Learning* (pp.779):
#
# >Part 1:	Frame the problem and look at the big picture
# Part 2: Download and perform preliminary exploration of the data
# Part 3: Clean the Data: Drop, Impute, and Encode
# Part 4: Explore Feature Relationships
# Part 5: Investigate Feature Engineering options to better expose the underlying data patterns
#
# ### The Dataset
#
# All teams will use the same dataset. It is a smaller version of the Zillow housing dataset that was used in the
# Zillow Million Dollar Prize which ran on Kaggle in 2017 (sorry, the contest is closed, so you can't win any money
# with this project!).  We will try to predict the assessed tax value (`'taxvaluedollarcnt'`) of the property from a large collection
# of descriptors. Some features are closely related and some are obviously useless.  There are potential outliers and also quite a few missing values.
#
# This is a good example of a dataset which has not been predigested for you on Kaggle, and should give you a good chance to
# try all the various tools in your toolbox!

# %%
# =============================
# Useful Imports
# =============================

# Standard Libraries
import os
import time
import math
import io
import zipfile
import requests
from urllib.parse import urlparse
from itertools import chain, combinations

# Data Science Libraries
import numpy as np
import pandas as pd
import seaborn as sns

# Visualization
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib.ticker as mticker  # Optional: Format y-axis labels as dollars

# Scikit-learn (Machine Learning)
from sklearn.model_selection import (
    train_test_split, 
    cross_val_score, 
    GridSearchCV, 
    RandomizedSearchCV, 
    RepeatedKFold
)
from sklearn.preprocessing import StandardScaler, OrdinalEncoder
from sklearn.impute import SimpleImputer
from sklearn.metrics import mean_squared_error
from sklearn.feature_selection import SequentialFeatureSelector, f_regression, SelectKBest
from sklearn.datasets import make_regression
from sklearn.ensemble import BaggingRegressor, RandomForestRegressor, GradientBoostingRegressor

# Kaggle and Progress Tracking
from tqdm import tqdm

# =============================
# Global Variables
# =============================
random_state = 42

# =============================
# Utility Functions
# =============================

# Format y-axis labels as dollars with commas (optional)
def dollar_format(x, pos):
    return f'${x:,.0f}'

# Convert seconds to HH:MM:SS format
def format_hms(seconds):
    return time.strftime("%H:%M:%S", time.gmtime(seconds))

# %% [markdown]
# ## Prelude: Download the Zillow Housing Dataset
#
# The code cell below will load the dataset for you.
#
# > **Notice that before downloading, this cell first checks whether the files already exist.**
#
# For a detailed description of the dataset features, please refer to  **Appendix 1** below.
#
# **Note:** Do **not** perform a train/test split for this milestone (unlike HOML suggests), since you need to do the split **after** any data preparation and feature engineering. You can wait until Milestone 2 to do the split.

# %%
url = "https://www.cs.bu.edu/fac/snyder/cs505/Data/zillow_dataset.csv"

filename = os.path.basename(urlparse(url).path)

if not os.path.exists(filename):
    try:
        print("Downloading the file...")
        response = requests.get(url)
        response.raise_for_status()  # Raise an error for bad status codes
        with open(filename, "wb") as f:
            f.write(response.content)
        print("File downloaded successfully.")
    except requests.exceptions.RequestException as e:
        print(f"Error downloading the file: {e}")
else:
    print("File already exists. Skipping download.")

df = pd.read_csv(filename)
# Out:
# File already exists. Skipping download.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77613 entries, 0 to 77612
# Data columns (total 55 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   parcelid                      77613 non-null  int64
#  1   airconditioningtypeid         25007 non-null  float64
#  2   architecturalstyletypeid      207 non-null    float64
#  3   basementsqft                  50 non-null     float64
#  4   bathroomcnt                   77579 non-null  float64
#  5   bedroomcnt                    77579 non-null  float64
#  6   buildingclasstypeid           15 non-null     float64
#  7   buildingqualitytypeid         49809 non-null  float64
#  8   calculatedbathnbr             76963 non-null  float64
#  9   decktypeid                    614 non-null    float64
#  10  finishedfloor1squarefeet      6037 non-null   float64
#  11  calculatedfinishedsquarefeet  77378 non-null  float64
#  12  finishedsquarefeet12          73923 non-null  float64
#  13  finishedsquarefeet13          42 non-null     float64
#  14  finishedsquarefeet15          3027 non-null   float64
#  15  finishedsquarefeet50          6037 non-null   float64
#  16  finishedsquarefeet6           386 non-null    float64
#  17  fips                          77579 non-null  float64
#  18  fireplacecnt                  8289 non-null   float64
#  19  fullbathcnt                   76963 non-null  float64
#  20  garagecarcnt                  25520 non-null  float64
#  21  garagetotalsqft               25520 non-null  float64
#  22  hashottuborspa                1539 non-null   object
#  23  heatingorsystemtypeid         49571 non-null  float64
#  24  latitude                      77579 non-null  float64
#  25  longitude                     77579 non-null  float64
#  26  lotsizesquarefeet             69321 non-null  float64
#  27  poolcnt                       16174 non-null  float64
#  28  poolsizesum                   869 non-null    float64
#  29  pooltypeid10                  465 non-null    float64
#  30  pooltypeid2                   1074 non-null   float64
#  31  pooltypeid7                   15079 non-null  float64
#  32  propertycountylandusecode     77579 non-null  object
#  33  propertylandusetypeid         77579 non-null  float64
#  34  propertyzoningdesc            50476 non-null  object
#  35  rawcensustractandblock        77579 non-null  float64
#  36  regionidcity                  76107 non-null  float64
#  37  regionidcounty                77579 non-null  float64
#  38  regionidneighborhood          30974 non-null  float64
#  39  regionidzip                   77529 non-null  float64
#  40  roomcnt                       77579 non-null  float64
#  41  storytypeid                   50 non-null     float64
#  42  threequarterbathnbr           10106 non-null  float64
#  43  typeconstructiontypeid        223 non-null    float64
#  44  unitcnt                       50703 non-null  float64
#  45  yardbuildingsqft17            2393 non-null   float64
#  46  yardbuildingsqft26            70 non-null     float64
#  47  yearbuilt                     77309 non-null  float64
#  48  numberofstories               17599 non-null  float64
#  49  fireplaceflag                 172 non-null    object
#  50  assessmentyear                77579 non-null  float64
#  51  taxdelinquencyflag            2900 non-null   object
#  52  taxdelinquencyyear            2900 non-null   float64
#  53  censustractandblock           77332 non-null  float64
#  54  taxvaluedollarcnt             77578 non-null  float64
# dtypes: float64(49), int64(1), object(5)
# memory usage: 32.6+ MB

# %% [markdown]
# ## Part 1: Frame the problem and look at the big picture [3 pts]
#
# This part is a bit vague, since this project is not taking place in an actual business, but for the sake of exercizing all the steps, **pretend** that you are working at Zillow as a data analyst and are given this dataset and asked to
# - Analyze and understand the data;
# - Create a regression model;
# - Give a presentation to the marketing team about your results.
#
# #### **1 Discussion:**
#
# AFTER doing your EDA, come back and answer each of the following 3 questions in a *concise and informative paragraph between the lines;* you may wish to use your own business or home-buying experience, or to do some online research about the issues before you propose your ideas. (Don't stress about this, but *humor your professor and give it your best shot!*)

# %% [markdown]
#     The business objective is to predict the target (tax dollar amount) given the 55 features contained in the original dataset, find out which of those features is most relevant to predicting the target, and eventually use that feature or combination of features to make a prediction and give insight to the marketing department. The marketing team may then use that insight to make more targeted advertisements. For example, if we discover that the amount of square feet and location has a higher impact on the value of a home (as indicated through our target variable of tax dollar amount), then the team may advertise to a limited demographic who they believe would be most likely to make an offer on that particular house. On the data science side, success will be measured by using various metrics to confirm the accuracy of our models before making predictions, using such metrics as mean squared error, mean root squared error, F1 square, Accuracy and Recall as necessary. Success on the marketing side will depend on our findings, and be measured by the amount of marketing efforts that result in successful purchases with the least amount of time on the market.

# %% [markdown]
# **1.1:**
#      What is the objective of this project in business terms?

# %% [markdown]
# **1.2:**  How will your solution be used?

# %% [markdown]
# **1.3:**  How should success (or failure) be measured?

# %% [markdown]
# ## Part 2: Download and perform preliminary exploration of the data [4 pts]
#
# ### Part 2.A: Load the data into a dataframe and study each feature/column and its characteristics:
# - Name
# - Type (categorical, int/float, text, etc.)
# - Apparent usefulness for the task
# - Approximate % of missing values
# - How many unique values
#
# **Note:** The **target** is the last column `'taxvaluedollarcnt'` -- pay particular attention to this during the EDA process.
#
# Hint: Just use `.head()`, `.info()`, and `.nunique()`.

# %%
df.nunique()
# Out:
# parcelid                        77414
# airconditioningtypeid               5
# architecturalstyletypeid            5
# basementsqft                       43
# bathroomcnt                        22
# bedroomcnt                         16
# buildingclasstypeid                 2
# buildingqualitytypeid              12
# calculatedbathnbr                  21
# decktypeid                          1
# finishedfloor1squarefeet         1787
# calculatedfinishedsquarefeet     4972
# finishedsquarefeet12             4868
# finishedsquarefeet13               13
# finishedsquarefeet15             1724
# finishedsquarefeet50             1807
# finishedsquarefeet6               350
# fips                                3
# fireplacecnt                        5
# fullbathcnt                        13
# garagecarcnt                       14
# garagetotalsqft                   839
# hashottuborspa                      1
# heatingorsystemtypeid              10
# latitude                        64038
# longitude                       62461
# lotsizesquarefeet               18848
# poolcnt                             1
# poolsizesum                       262
# pooltypeid10                        1
# pooltypeid2                         1
# pooltypeid7                         1
# propertycountylandusecode          75
# propertylandusetypeid              13
# propertyzoningdesc               1907
# rawcensustractandblock          39188
# regionidcity                      175
# regionidcounty                      3
# regionidneighborhood              480
# regionidzip                       389
# roomcnt                            16
# storytypeid                         1
# threequarterbathnbr                 4
# typeconstructiontypeid              4
# unitcnt                             8
# yardbuildingsqft17                540
# yardbuildingsqft26                 59
# yearbuilt                         136
# numberofstories                     4
# fireplaceflag                       1
# assessmentyear                      1
# taxdelinquencyflag                  1
# taxdelinquencyyear                 13
# censustractandblock             39006
# taxvaluedollarcnt               50949
# dtype: int64

# %%
df.head()
# Out:
#    parcelid  airconditioningtypeid  architecturalstyletypeid  basementsqft  \
# 0  14297519                    NaN                       NaN           NaN
# 1  17052889                    NaN                       NaN           NaN
# 2  14186244                    NaN                       NaN           NaN
# 3  12177905                    NaN                       NaN           NaN
# 4  10887214                    1.0                       NaN           NaN
#
#    bathroomcnt  bedroomcnt  buildingclasstypeid  buildingqualitytypeid  \
# 0          3.5         4.0                  NaN                    NaN
# 1          1.0         2.0                  NaN                    NaN
# 2          2.0         3.0                  NaN                    NaN
# 3          3.0         4.0                  NaN                    8.0
# 4          3.0         3.0                  NaN                    8.0
#
#    calculatedbathnbr  decktypeid  ...  yardbuildingsqft17  yardbuildingsqft26  \
# 0                3.5         NaN  ...                 NaN                 NaN
# 1                1.0         NaN  ...                 NaN                 NaN
# 2                2.0         NaN  ...                 NaN                 NaN
# 3                3.0         NaN  ...                 NaN                 NaN
# 4                3.0         NaN  ...                 NaN                 NaN
#
#    yearbuilt  numberofstories  fireplaceflag  assessmentyear  \
# 0     1998.0              NaN            NaN          2016.0
# 1     1967.0              1.0            NaN          2016.0
# 2     1962.0              1.0            NaN          2016.0
# 3     1970.0              NaN            NaN          2016.0
# 4     1964.0              NaN            NaN          2016.0
#
#    taxdelinquencyflag  taxdelinquencyyear  censustractandblock  \
# 0                 NaN                 NaN         6.059063e+13
# 1                 NaN                 NaN         6.111001e+13
# 2                 NaN                 NaN         6.059022e+13
# 3                 NaN                 NaN         6.037300e+13
# 4                 NaN                 NaN         6.037124e+13
#
#    taxvaluedollarcnt
# 0          1023282.0
# 1           464000.0
# 2           564778.0
# 3           145143.0
# 4           119407.0
#
# [5 rows x 55 columns]

# %%
df.describe()
# Out:
#            parcelid  airconditioningtypeid  architecturalstyletypeid  \
# count  7.761300e+04           25007.000000                207.000000
# mean   1.300781e+07               1.812013                  7.386473
# std    3.518717e+06               2.965768                  2.728030
# min    1.071186e+07               1.000000                  2.000000
# 25%    1.153821e+07               1.000000                  7.000000
# 50%    1.253004e+07               1.000000                  7.000000
# 75%    1.421101e+07               1.000000                  7.000000
# max    1.676893e+08              13.000000                 21.000000
#
#        basementsqft   bathroomcnt    bedroomcnt  buildingclasstypeid  \
# count     50.000000  77579.000000  77579.000000            15.000000
# mean     679.720000      2.298496      3.053223             3.933333
# std      689.703546      0.996732      1.140480             0.258199
# min       38.000000      0.000000      0.000000             3.000000
# 25%      273.000000      2.000000      2.000000             4.000000
# 50%      515.000000      2.000000      3.000000             4.000000
# 75%      796.500000      3.000000      4.000000             4.000000
# max     3560.000000     18.000000     16.000000             4.000000
#
#        buildingqualitytypeid  calculatedbathnbr  decktypeid  ...  \
# count           49809.000000       76963.000000       614.0  ...
# mean                6.533779           2.316392        66.0  ...
# std                 1.722062           0.979689         0.0  ...
# min                 1.000000           1.000000        66.0  ...
# 25%                 6.000000           2.000000        66.0  ...
# 50%                 6.000000           2.000000        66.0  ...
# 75%                 8.000000           3.000000        66.0  ...
# max                12.000000          18.000000        66.0  ...
#
#        typeconstructiontypeid       unitcnt  yardbuildingsqft17  \
# count              223.000000  50703.000000         2393.000000
# mean                 6.040359      1.110309          305.460928
# std                  0.556035      1.169967          238.735241
# min                  4.000000      1.000000           11.000000
# 25%                  6.000000      1.000000          170.000000
# 50%                  6.000000      1.000000          250.000000
# 75%                  6.000000      1.000000          364.000000
# max                 13.000000    237.000000         3191.000000
#
#        yardbuildingsqft26     yearbuilt  numberofstories  assessmentyear  \
# count           70.000000  77309.000000     17599.000000         77579.0
# mean           216.385714   1968.611507         1.434286          2016.0
# std            190.177514     23.793171         0.544515             0.0
# min             12.000000   1824.000000         1.000000          2016.0
# 25%             61.500000   1953.000000         1.000000          2016.0
# 50%            164.500000   1970.000000         1.000000          2016.0
# 75%            310.500000   1987.000000         2.000000          2016.0
# max            868.000000   2016.000000         6.000000          2016.0
#
#        taxdelinquencyyear  censustractandblock  taxvaluedollarcnt
# count         2900.000000         7.733200e+04       7.757800e+04
# mean            14.088276         6.049667e+13       4.901506e+05
# std              2.181281         1.533339e+12       6.537979e+05
# min              3.000000         6.037101e+13       1.000000e+03
# 25%             14.000000         6.037311e+13       2.068985e+05
# 50%             15.000000         6.037603e+13       3.588785e+05
# 75%             15.000000         6.059042e+13       5.690000e+05
# max             99.000000         4.830301e+14       4.906124e+07
#
# [8 rows x 50 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77613 entries, 0 to 77612
# Data columns (total 55 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   parcelid                      77613 non-null  int64
#  1   airconditioningtypeid         25007 non-null  float64
#  2   architecturalstyletypeid      207 non-null    float64
#  3   basementsqft                  50 non-null     float64
#  4   bathroomcnt                   77579 non-null  float64
#  5   bedroomcnt                    77579 non-null  float64
#  6   buildingclasstypeid           15 non-null     float64
#  7   buildingqualitytypeid         49809 non-null  float64
#  8   calculatedbathnbr             76963 non-null  float64
#  9   decktypeid                    614 non-null    float64
#  10  finishedfloor1squarefeet      6037 non-null   float64
#  11  calculatedfinishedsquarefeet  77378 non-null  float64
#  12  finishedsquarefeet12          73923 non-null  float64
#  13  finishedsquarefeet13          42 non-null     float64
#  14  finishedsquarefeet15          3027 non-null   float64
#  15  finishedsquarefeet50          6037 non-null   float64
#  16  finishedsquarefeet6           386 non-null    float64
#  17  fips                          77579 non-null  float64
#  18  fireplacecnt                  8289 non-null   float64
#  19  fullbathcnt                   76963 non-null  float64
#  20  garagecarcnt                  25520 non-null  float64
#  21  garagetotalsqft               25520 non-null  float64
#  22  hashottuborspa                1539 non-null   object
#  23  heatingorsystemtypeid         49571 non-null  float64
#  24  latitude                      77579 non-null  float64
#  25  longitude                     77579 non-null  float64
#  26  lotsizesquarefeet             69321 non-null  float64
#  27  poolcnt                       16174 non-null  float64
#  28  poolsizesum                   869 non-null    float64
#  29  pooltypeid10                  465 non-null    float64
#  30  pooltypeid2                   1074 non-null   float64
#  31  pooltypeid7                   15079 non-null  float64
#  32  propertycountylandusecode     77579 non-null  object
#  33  propertylandusetypeid         77579 non-null  float64
#  34  propertyzoningdesc            50476 non-null  object
#  35  rawcensustractandblock        77579 non-null  float64
#  36  regionidcity                  76107 non-null  float64
#  37  regionidcounty                77579 non-null  float64
#  38  regionidneighborhood          30974 non-null  float64
#  39  regionidzip                   77529 non-null  float64
#  40  roomcnt                       77579 non-null  float64
#  41  storytypeid                   50 non-null     float64
#  42  threequarterbathnbr           10106 non-null  float64
#  43  typeconstructiontypeid        223 non-null    float64
#  44  unitcnt                       50703 non-null  float64
#  45  yardbuildingsqft17            2393 non-null   float64
#  46  yardbuildingsqft26            70 non-null     float64
#  47  yearbuilt                     77309 non-null  float64
#  48  numberofstories               17599 non-null  float64
#  49  fireplaceflag                 172 non-null    object
#  50  assessmentyear                77579 non-null  float64
#  51  taxdelinquencyflag            2900 non-null   object
#  52  taxdelinquencyyear            2900 non-null   float64
#  53  censustractandblock           77332 non-null  float64
#  54  taxvaluedollarcnt             77578 non-null  float64
# dtypes: float64(49), int64(1), object(5)
# memory usage: 32.6+ MB

# %%
def show_null_counts_features(df):
    # Count the nulls and calculate the %
    count_nulls = df.isnull().sum()
    df_nulls = (df.isnull().mean() * 100).round(2)
    
    # Determine if the column is numeric or non-numeric
    feature_types = df.dtypes.apply(lambda x: 'Numeric' if np.issubdtype(x, np.number) else 'Categorical')
    
    # Filter out the columns with missing values and sort them in descending order
    missing_data = pd.DataFrame({
        'Feature': count_nulls[count_nulls > 0].index,
        '# Null Values': count_nulls[count_nulls > 0].values, 
        'Null %': df_nulls[df_nulls > 0].values,
        'Type': feature_types[count_nulls > 0].values
    }).sort_values(by='Null %', ascending=False)
    
    print(f'The dataset contains {len(df)} samples.\n')

    if (len(missing_data) == 0):
        print("There are no null values in the dataset!")
    else:
        # Print null value stats
        print('Feature Name    # Nulls      Null %    Type')
        print('------------    -------      ------    ----')
        for index, row in missing_data.iterrows():
            print(f"{row['Feature']:<15} {row['# Null Values']:<12} {row['Null %']:.2f}%   {row['Type']}")


# Uncomment to see results
            
show_null_counts_features(df)
# Out:
# The dataset contains 77613 samples.
#
# Feature Name    # Nulls      Null %    Type
# ------------    -------      ------    ----
# buildingclasstypeid 77598        99.98%   Numeric
# finishedsquarefeet13 77571        99.95%   Numeric
# basementsqft    77563        99.94%   Numeric
# storytypeid     77563        99.94%   Numeric
# yardbuildingsqft26 77543        99.91%   Numeric
# fireplaceflag   77441        99.78%   Categorical
# architecturalstyletypeid 77406        99.73%   Numeric
# typeconstructiontypeid 77390        99.71%   Numeric
# finishedsquarefeet6 77227        99.50%   Numeric
# pooltypeid10    77148        99.40%   Numeric
# decktypeid      76999        99.21%   Numeric
# poolsizesum     76744        98.88%   Numeric
# pooltypeid2     76539        98.62%   Numeric
# hashottuborspa  76074        98.02%   Categorical
# yardbuildingsqft17 75220        96.92%   Numeric
# taxdelinquencyflag 74713        96.26%   Categorical
# taxdelinquencyyear 74713        96.26%   Numeric
# finishedsquarefeet15 74586        96.10%   Numeric
# finishedfloor1squarefeet 71576        92.22%   Numeric
# finishedsquarefeet50 71576        92.22%   Numeric
# fireplacecnt    69324        89.32%   Numeric
# threequarterbathnbr 67507        86.98%   Numeric
# pooltypeid7     62534        80.57%   Numeric
# poolcnt         61439        79.16%   Numeric
# numberofstories 60014        77.32%   Numeric
# airconditioningtypeid 52606        67.78%   Numeric
# garagecarcnt    52093        67.12%   Numeric
# garagetotalsqft 52093        67.12%   Numeric
# regionidneighborhood 46639        60.09%   Numeric
# heatingorsystemtypeid 28042        36.13%   Numeric
# buildingqualitytypeid 27804        35.82%   Numeric
# propertyzoningdesc 27137        34.96%   Categorical
# unitcnt         26910        34.67%   Numeric
# lotsizesquarefeet 8292         10.68%   Numeric
# finishedsquarefeet12 3690         4.75%   Numeric
# regionidcity    1506         1.94%   Numeric
# calculatedbathnbr 650          0.84%   Numeric
# fullbathcnt     650          0.84%   Numeric
# yearbuilt       304          0.39%   Numeric
# censustractandblock 281          0.36%   Numeric
# calculatedfinishedsquarefeet 235          0.30%   Numeric
# regionidzip     84           0.11%   Numeric
# taxvaluedollarcnt 35           0.05%   Numeric
# fips            34           0.04%   Numeric
# bathroomcnt     34           0.04%   Numeric
# bedroomcnt      34           0.04%   Numeric
# regionidcounty  34           0.04%   Numeric
# rawcensustractandblock 34           0.04%   Numeric
# propertycountylandusecode 34           0.04%   Categorical
# propertylandusetypeid 34           0.04%   Numeric
# longitude       34           0.04%   Numeric
# latitude        34           0.04%   Numeric
# roomcnt         34           0.04%   Numeric
# assessmentyear  34           0.04%   Numeric

# %% [markdown]
# #### **2.A Discussion:** Answer the following questions.
#
# **2.A.1:**  Which features are categorical?
# These two features are categorical: propertycountylandusecode, and propertyzoningdesc

# %% [markdown]
# **2.A.2:**  Are there any features which appear at first glance to be **useless** for the business purpose of this project and should be deleted?  Give examples and describe your reasoning briefly.
#
# Parcelid is a number that appears to be random, so it will be completely useless in trying to make any predictions. For that reason it will be dropped.

# %% [markdown]
# **2.A.3:**  Are there any features which appear to be **useless** because of the percentage of missing values?  If so, give an example.
#
# These features all contained more than 60% null data, so we decided to drop them as we felt that trying to impute data based on more than 60% missing data could result in computationally expensive, more complex, and potentially innacurate imputation that could skew our prediction. airconditioningtypeid, architecturalstyletypeid, basementsqft, buildingclasstypeid, finishedfloor1squarefeet,
# finishedsquarefeet13, finishedsquarefeet15, finishedsquarefeet50, finishedsquarefeet6, fireplacecnt, garagecarcnt, garagetotalsqft, hashottuborspa, poolsizesum,
# threequarterbathnbr, typeconstructiontypeid, yardbuildingsqft17, yardbuildingsqft26, numberofstories, fireplaceflag, taxdelinquencyflag, and taxdelinquencyyear

# %% [markdown]
# **2.A.4:**  Are there any features which appear to be **useless** because of the number of unique values?  If so, give an example.
# These features: decktypeid, poolcnt, pooltypeid10, pooltypeid2, pooltypeid7, regionidzip, storytypeid, unitcnt, lattitude, longitude, assessmentyear, and censustractandblock;
# we ultimately decided to remove because they showed only 1 value populated. That will not help us to make any useful predictions.

# %% [markdown]
# ### Part 2.B: Exploratory Data Analysis (EDA) -- Feature-Level Visualization
#
# - To get an overview, generate histograms for all features using `df.hist()`  (Hint: increase the figsize and set the layout to `(-1,m)` to get  `m` columns and as many rows as necessary.)
# - Generate individual visualizations for the **target and three (3)** other interesting-looking features in the dataset (i.e., a total of 4):
#     - Use appropriate plot types (e.g., histograms and boxplots for numerical features, bar plots for categorical features) to understand distributions and identify potential outliers for these three.
#     - Use as many code cells as you need, and give comments describing what each cell does.
#     - Answer the discussion question posed (you should choose 3 features for which you can say something interesting in the discussion).

# %%
plt.figure(figsize = (30, 60))
df.hist(bins = 10, figsize = (30, 60), layout = (-1, 6))
plt.tight_layout()
plt.show()

# %%
yearbuilt = df["yearbuilt"].value_counts()
yardbuildingsqft26 = df["yardbuildingsqft26"].value_counts()
finishedfloor1squarefeet = df["finishedfloor1squarefeet"].value_counts()
taxvaluedollarcnt = df["taxvaluedollarcnt"].value_counts()

plt.figure(figsize=(14, 18))

year_bins = pd.cut(df["yearbuilt"], bins=range(1870, 2021, 10))  # every 10 years
year_counts = year_bins.value_counts().sort_index()

plt.subplot(4, 1, 1)
year_counts.plot(kind="bar")
plt.title("Year Built (Grouped by Decade)")
plt.xlabel("Decade")
plt.ylabel("Frequency")
plt.xticks(rotation=45, ha='right')

# 2. Grouped Yard Building Sqft
yard_bins = pd.cut(df["yardbuildingsqft26"], bins=20)  # adjust bin count as needed
yard_counts = yard_bins.value_counts().sort_index()

plt.subplot(4, 1, 2)
yard_counts.plot(kind="bar")
plt.title("Yard Building Sqft (Binned)")
plt.xlabel("Sqft Range")
plt.ylabel("Frequency")
plt.xticks(rotation=45, ha='right')


floor_bins = pd.cut(df["finishedfloor1squarefeet"], bins=30)  # Adjust bins as needed
floor_counts = floor_bins.value_counts().sort_index()

plt.subplot(4, 1, 3)
floor_counts.plot(kind="bar")
plt.title("Finished Floor 1 Sqft (Binned)")
plt.xlabel("Sqft Range")
plt.ylabel("Frequency")
plt.xticks(rotation=45, ha='right')


# TEMPORARY log transform without modifying df
log_tax = np.log1p(df["taxvaluedollarcnt"])  # log(1 + x)

# Bin log-transformed values
tax_bins = pd.cut(log_tax, bins=50)
tax_counts = tax_bins.value_counts().sort_index()

# Plot: Log Tax Value Dollar Count (Binned)
plt.subplot(4, 1, 4)
ax = tax_counts.plot(kind="bar")
plt.title("Log Tax Value Dollar Count (Binned)")
plt.xlabel("Log(Value Range)")
plt.ylabel("Frequency")

# Optional: space out ticks
tick_locs = range(0, len(tax_counts), 5)
tick_labels = [str(tax_counts.index[i]) for i in tick_locs]
plt.xticks(tick_locs, tick_labels, rotation=45, ha="right")


plt.tight_layout()
plt.show()

# %% [markdown]
# #### **2.B Discussion:** Describe in a paragraph what you learned in your detailed examination of the features you explored:
# - What is the distribution (normal, exponential, etc.) if any?
# - Any problems (e.g., outliers, any odd characteristics)?
# - Anything else interesting? Why did you choose it?
#
#
# The Year Built graph is a multimodal, left skewed distribution. It has a few peaks, and the concentration of data is between 1950 and 2010. There are outliers both to the left and right, with more being on the left side. We chose this graph because at first one would think that newer houses automatically would sell for more. We are curious to see if that holds true later on in our analysis. The Yard Building Sqft is right skewed, with a long tail. This indicates that there are very large values among the outliers. Most of the data falls within the 11.144 - 226 range, and that can be incredibly useful when trying to make a prediction our your normal house tax amount vs the outliers. It may help us separate them out to make more accurate predictions later on. The Finished Floor 1 Sqft graph is right skewed, log normal. The mode is somewhere between 1000-1500 sqft, and this graph shows a very long right skewed tail with outliers containing larger sqft. This is an interesting feature that will help us to make predictions excluding outliers based on a normal distribution. The log tax value dollar count graph is a mostly normal distribution. There is a very slight right skew to this graph, but otherwise is looks normal. We originally had the graph displaying raw data, which showed a heavy right skew, but the data was not legible or useable beyond that point, so we ultimately decided to convert it to the log.

# %% [markdown]
# ## Part 3:  Clean the Data: Drop, Impute, and Encode [6 pts]
#
#
#
# **Important Notes:**
# - You should review your Homework 4 before doing this section!
# - Create new names for modified data at each stage to avoid problems with global variables.
# - Whenever possible, write functions for all data transformations you apply, for these reasons:
#     - So you can easily prepare the data the next time you get a fresh dataset
#     - So you can apply these transformations in future projects
#     - To clean and prepare new data instances once your solution is live
#     - To make it easy to treat your preparation choices as hyperparameters
#     - [To apply the same transformations to your test set if train/test split already done -- not applicable here]

# %% [markdown]
# ### Part 3.A: Drop features you judge to be unsuitable for the regression task
#
# Your call, based on any research you can do to understand the feature (hopefully IRL you would have a domain expert to help with this, but do your best).
#
# Note: Do not drop features because of too many missing values, that's the next task!

# %%
df.drop(columns = ["parcelid", "decktypeid", "poolcnt", "pooltypeid10", "pooltypeid2", "pooltypeid7", "regionidzip", "storytypeid", "unitcnt", "assessmentyear", "censustractandblock"], inplace = True)

# %% [markdown]
# #### **3.A Discussion:** Justify in a paragraph your decisions about which features to drop.
#
# We began by examining the features contained within this dataset, and deciding which were the least useful to our use case. Parcelid was dropped for instance, because it is completely unique, but doesn't tell us anything in relation to our target variable. The rest of the features we removed mostly contained data with only one value. While this might be useful in other use cases, for our purposes those features were judged to be useless and therefore dropped.

# %% [markdown]
# ### Part 3.B: Drop **features** with "too many" null values
#
# Your code in the next cell(s). Make a judgement call about what "too many" means and briefly describe your reasoning in the discussion.
#
# Note: "Too many" may depend on what the non-null values look like, be sure to investigate carefully.

# %%
max_nulls = 50000     

# Count null values per column

count_nulls = df.isnull().sum()

# Filter out columns where null count exceeds max_nulls

filtered_df = count_nulls[count_nulls > max_nulls].index

# Drop the columns

df_clean = df.drop(filtered_df, axis = 1)
df_clean.to_csv("zillow_cleaned_somewhat.csv",index=False)


# Uncomment to verify they were removed

show_null_counts_features(df_clean)
# Out:
# The dataset contains 77613 samples.
#
# Feature Name    # Nulls      Null %    Type
# ------------    -------      ------    ----
# regionidneighborhood 46639        60.09%   Numeric
# heatingorsystemtypeid 28042        36.13%   Numeric
# buildingqualitytypeid 27804        35.82%   Numeric
# propertyzoningdesc 27137        34.96%   Categorical
# lotsizesquarefeet 8292         10.68%   Numeric
# finishedsquarefeet12 3690         4.75%   Numeric
# regionidcity    1506         1.94%   Numeric
# fullbathcnt     650          0.84%   Numeric
# calculatedbathnbr 650          0.84%   Numeric
# yearbuilt       304          0.39%   Numeric
# calculatedfinishedsquarefeet 235          0.30%   Numeric
# taxvaluedollarcnt 35           0.05%   Numeric
# bathroomcnt     34           0.04%   Numeric
# bedroomcnt      34           0.04%   Numeric
# propertylandusetypeid 34           0.04%   Numeric
# propertycountylandusecode 34           0.04%   Categorical
# longitude       34           0.04%   Numeric
# latitude        34           0.04%   Numeric
# fips            34           0.04%   Numeric
# rawcensustractandblock 34           0.04%   Numeric
# regionidcounty  34           0.04%   Numeric
# roomcnt         34           0.04%   Numeric

# %%
categorical_features = df_clean.select_dtypes(exclude=['number']).columns.tolist()
numeric_features     = df_clean.select_dtypes(include=['number']).columns.tolist()

print(categorical_features)
print(numeric_features)
# Out:
# ['propertycountylandusecode', 'propertyzoningdesc']
# ['bathroomcnt', 'bedroomcnt', 'buildingqualitytypeid', 'calculatedbathnbr', 'calculatedfinishedsquarefeet', 'finishedsquarefeet12', 'fips', 'fullbathcnt', 'heatingorsystemtypeid', 'latitude', 'longitude', 'lotsizesquarefeet', 'propertylandusetypeid', 'rawcensustractandblock', 'regionidcity', 'regionidcounty', 'regionidneighborhood', 'roomcnt', 'yearbuilt', 'taxvaluedollarcnt']

# %%
X = df_clean.drop("taxvaluedollarcnt", axis=1)
y = df_clean["taxvaluedollarcnt"]

# %% [markdown]
# #### **3.B Discussion:** In a paragraph, explain your decision about which features were dropped
#
# We began by creating a view that counted null rows per feature and calculated the percentage of nulls against the total. We then observed dramatic shifts in the amounts of nulls as a percentage. These occured largely at 30% and roughly 60%. We noted that there were some features that could be valuable with imputation for the data under 60%. We also found that the data that contained over 60% null would be more difficult to impute, and that the data itself didn't seem to be particularly useful. After some quick calculation, we took the row count associated with the 60%, and decided to round to an even 60,000 null count to drop the features.

# %% [markdown]
# ### Part 3.C: Drop Problematic **samples**
#
# There could be several reasons why you might want to drop a sample:
# - It has  "too many" null values
# - It has a null value in the target
# - It contains outliers, especially in the target
#
# We began by
#
#
# Your code in the next cell(s). Make a judgement call about which samples should be dropped and briefly describe your reasoning in the discussion.

# %%
mask = y.notnull()
X = X[mask]
y = y[mask]

Q1 = y.quantile(0.25)
Q3 = y.quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Get mask of rows to keep
inliers = (y >= lower_bound) & (y <= upper_bound)

# %%
X = X[inliers]
y = y[inliers]

# %% [markdown]
# #### **3.C Discussion:** In a short paragraph, explain your decision about which samples were dropped
#
# When it came to thinking about how to approach dropping certain samples, we started by reviewing high level metrics such as standard deviation. We noticed that to begin with, we had a standard deviation of over 7. To fix this, we decided to isolate the outliers, using Interquartile Range. We were able to keep only the inliers in our dataset. Consequently, the 35 null target values were treated as outliers and also removed. The records with too many null values were previously removed.

# %% [markdown]
# ### Part 3.D: Impute for the remaining missing values
#
# Review the methods for imputation in **Appendix 2** and choose how you will impute the remainder of the missing values. Note:
# - Consider whether different methods are justified for different features.
# - In the next cells, apply your imputation methods to the dataset so that no null values remain after this step.
# - Answer the discussion question.

# %%
# print(y.isnull().sum())

# 2. Identify categorical columns
categorical_features = X.select_dtypes(include=['object', 'category']).columns
numeric_features = X.select_dtypes(include=['number']).columns


# 3. Impute missing values in categorical columns
cat_imputer = SimpleImputer(strategy='most_frequent')
X[categorical_features] = cat_imputer.fit_transform(X[categorical_features])


num_imputer = SimpleImputer(strategy='median')
X[numeric_features] = num_imputer.fit_transform(X[numeric_features])

# %% [markdown]
# #### **3.D Discussion:**  Describe in a paragraph your decisions about which methods you used to impute missing values in the dataset
#
# As we're still in the EDA phase, we chose to employ a more simplistic but intuitive approach to imputation. We started by splitting the categorical features from the numeric features. We then used most frequent to impute the categorical values. We chose this method because it will preserve the distribution without introducing skew, and it's computationally inexpensive. When it came to imputing the numerical features, we chose to impute the median. We felt that this was similarly intuitive, that it would not introduce skew, and it tends to be unaffected by outliers.

# %% [markdown]
# ### 3.E: Encode the Categorical Features (if any)
#
# You may not have any categorical features. If you do, encode them in the next step. No discussion is necessary.

# %%
# 4. Encode categorical features and put them back safely
enc = OrdinalEncoder()
encoded_array = enc.fit_transform(X[categorical_features])
encoded_df = pd.DataFrame(encoded_array, columns=categorical_features, index=X.index)

# 5. Replace categorical columns with encoded values
X[categorical_features] = encoded_df

# 6. Optionally cast all to float64
X = X.astype('float64')

# 7. Inspect
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 72392 entries, 0 to 77612
# Data columns (total 21 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   bathroomcnt                   72392 non-null  float64
#  1   bedroomcnt                    72392 non-null  float64
#  2   buildingqualitytypeid         72392 non-null  float64
#  3   calculatedbathnbr             72392 non-null  float64
#  4   calculatedfinishedsquarefeet  72392 non-null  float64
#  5   finishedsquarefeet12          72392 non-null  float64
#  6   fips                          72392 non-null  float64
#  7   fullbathcnt                   72392 non-null  float64
#  8   heatingorsystemtypeid         72392 non-null  float64
#  9   latitude                      72392 non-null  float64
#  10  longitude                     72392 non-null  float64
#  11  lotsizesquarefeet             72392 non-null  float64
#  12  propertycountylandusecode     72392 non-null  float64
#  13  propertylandusetypeid         72392 non-null  float64
#  14  propertyzoningdesc            72392 non-null  float64
#  15  rawcensustractandblock        72392 non-null  float64
#  16  regionidcity                  72392 non-null  float64
#  17  regionidcounty                72392 non-null  float64
#  18  regionidneighborhood          72392 non-null  float64
#  19  roomcnt                       72392 non-null  float64
#  20  yearbuilt                     72392 non-null  float64
# dtypes: float64(21)
# memory usage: 12.2 MB

# %% [markdown]
# ## Part 4:  Investigate Feature Relationships  [6 pts]
#
# In this part, we will investigate the feature relationships as a way of understanding the data.  In the next part, we'll investigate potential feature engineering opportunities.
#
# **Note:**  We won't be committing to any changes to the data until Milestone 2, as our choice of transformations will very much depend on the model we're building. But investigating these aspects of the data is an essential step in the first stages of our project.
#
# ### Part 4.A:
#
#    - Compute and analyze pairwise correlations using a correlation matrix.
#    - Compute the F-statistic for all features for a better view of the relationships (displaying them in a bar chart would be useful as well).
#    - Identify features with strong correlations or notable relationships that may impact model performance.
#    - Investigate forward and backward feature selection
#         - Run these algorithms to investigate possible feature selection (don't commit to any selections yet)
#
# Your code below, in multiple cells with descriptive comments.

# %%
corr_matrix = X.corr()
plt.figure(figsize = (16, 12))
sns.heatmap(corr_matrix, annot = True, cmap = "coolwarm", fmt = ".1f")
plt.title("Correlation Matrix Heatmap")
plt.show()

# %%
n = len(y)
f_stats = {}

for col in X.columns:
    x = X[col]
    if x.var() == 0:  # Avoid divide-by-zero
        f_stats[col] = np.nan
        continue
    corr = np.corrcoef(x, y)[0, 1]  # Pearson correlation
    f = (corr**2 / (1 - corr**2)) * (n - 2)
    f_stats[col] = f

# Convert to DataFrame and sort
f_df = pd.DataFrame.from_dict(f_stats, orient='index', columns=['F-statistic'])
f_df = f_df.sort_values(by='F-statistic', ascending=False)

f_df  # Show top 10 features


f_df.plot(kind = "bar", figsize = (16, 12), legend = False)
plt.title("F-Statistic for All Features")
plt.xlabel("Feature")
plt.ylabel("F Statistic")
plt.tight_layout()
plt.show()

# %%
forward_model = RandomForestRegressor(n_estimators = 100, n_jobs = -1, random_state = 42)

# %%
def forward_feature_selection(X, y, model, 
                              scoring='neg_mean_squared_error', 
                              cv=5, 
                              tol=None,
                              max_features=None,
                              n_jobs=-1,
                              verbose=False):
    selected_features_forward = []
    remaining_features = list(X.columns)
    best_scores = []
    previous_score = float('inf')

    best_feature_set = None
    best_score_forward = float('inf')

    while remaining_features:
        scores = {}
        for feature in remaining_features:
            current_features = selected_features_forward + [feature]
            cv_score = -cross_val_score(
                model, X[current_features], y,
                scoring=scoring, cv=cv, n_jobs=n_jobs
            ).mean()
            scores[feature] = cv_score

        best_feature_forward = min(scores, key=scores.get)
        current_score = scores[best_feature_forward]

        if tol is not None and previous_score - current_score < tol:
            if verbose:
                print("Stopping early due to minimal improvement.")
            break

        selected_features_forward.append(best_feature_forward)
        best_scores.append(current_score)
        remaining_features.remove(best_feature_forward)
        previous_score = current_score

        if verbose:
            print(f"\nFeatures: {selected_features_forward[-3:]}, CV Score (MSE): {current_score:.4f}")

        if current_score < best_score_forward:
            best_score_forward = current_score
            best_feature_set = selected_features_forward.copy()

        if max_features is not None and len(selected_features_forward) >= max_features:
            break

    return (
        selected_features_forward,
        best_scores,
        best_feature_set,
        best_score_forward
    )

# %%
model = forward_model  # Already an instance or class

selected_features_forward, best_scores_forward, best_forward_features, best_score_forward = (
    forward_feature_selection(X, y, model, verbose=True)
)

# Plot the results
index = len(best_forward_features)

plt.figure(figsize=(10, 6))
plt.plot(range(1, len(best_scores_forward) + 1), best_scores_forward, marker='.')
plt.plot([index], [best_score_forward], marker='x', color='red')
plt.xticks(range(1, len(selected_features_forward) + 1), selected_features_forward, rotation=45, ha='right')
plt.title('Forward Feature Selection and CV Scores')
plt.xlabel('Features Added')
plt.ylabel('CV Score (MSE)')
plt.grid()
plt.tight_layout()
plt.show()

# Print the best subset and score
print(f"Best Features: {best_forward_features}")
print(f"Best CV Score: {best_score_forward:.4f}")
# Out:
# Features: ['rawcensustractandblock'], CV Score (MSE): 45394378845.2649
#
# Features: ['rawcensustractandblock', 'bathroomcnt'], CV Score (MSE): 37908162350.8198
#
# Features: ['rawcensustractandblock', 'bathroomcnt', 'propertycountylandusecode'], CV Score (MSE): 37168222745.3474
#
# Features: ['bathroomcnt', 'propertycountylandusecode', 'regionidcity'], CV Score (MSE): 37016975698.8599
#
# Features: ['propertycountylandusecode', 'regionidcity', 'propertylandusetypeid'], CV Score (MSE): 36913894753.4184
#
# Features: ['regionidcity', 'propertylandusetypeid', 'fullbathcnt'], CV Score (MSE): 36878558260.7530
#
# Features: ['propertylandusetypeid', 'fullbathcnt', 'regionidcounty'], CV Score (MSE): 36866971650.4453
#
# Features: ['fullbathcnt', 'regionidcounty', 'fips'], CV Score (MSE): 36860101745.3102
#
# Features: ['regionidcounty', 'fips', 'calculatedbathnbr'], CV Score (MSE): 36880557446.0774
#
# Features: ['fips', 'calculatedbathnbr', 'roomcnt'], CV Score (MSE): 37276508016.9391
#
# Features: ['calculatedbathnbr', 'roomcnt', 'heatingorsystemtypeid'], CV Score (MSE): 37834703771.3799
#
# Features: ['roomcnt', 'heatingorsystemtypeid', 'buildingqualitytypeid'], CV Score (MSE): 38297587555.8851
#
# Features: ['heatingorsystemtypeid', 'buildingqualitytypeid', 'regionidneighborhood'], CV Score (MSE): 38451044659.9869
#
# Features: ['buildingqualitytypeid', 'regionidneighborhood', 'calculatedfinishedsquarefeet_log'], CV Score (MSE): 38277271005.5688
#
# Features: ['regionidneighborhood', 'calculatedfinishedsquarefeet_log', 'yearbuilt'], CV Score (MSE): 36974798722.9831
#
# Features: ['calculatedfinishedsquarefeet_log', 'yearbuilt', 'lotsizesquarefeet'], CV Score (MSE): 36143597671.7343
#
# Features: ['yearbuilt', 'lotsizesquarefeet', 'latitude'], CV Score (MSE): 35568668523.3766
#
# Features: ['lotsizesquarefeet', 'latitude', 'longitude'], CV Score (MSE): 35033305118.7150
#
# Features: ['latitude', 'longitude', 'lotsizesquarefeet_log'], CV Score (MSE): 34966292697.7250
#
# Features: ['longitude', 'lotsizesquarefeet_log', 'bedroomcnt'], CV Score (MSE): 34927023669.0331
#
# Features: ['lotsizesquarefeet_log', 'bedroomcnt', 'calculatedfinishedsquarefeet'], CV Score (MSE): 34968074034.1127
#
# Features: ['bedroomcnt', 'calculatedfinishedsquarefeet', 'finishedsquarefeet12_log'], CV Score (MSE): 34953154637.9310
#
# Features: ['calculatedfinishedsquarefeet', 'finishedsquarefeet12_log', 'finishedsquarefeet12'], CV Score (MSE): 34984842488.0128
#
# Features: ['finishedsquarefeet12_log', 'finishedsquarefeet12', 'propertyzoningdesc'], CV Score (MSE): 35033159091.2197
# Best Features: ['rawcensustractandblock', 'bathroomcnt', 'propertycountylandusecode', 'regionidcity', 'propertylandusetypeid', 'fullbathcnt', 'regionidcounty', 'fips', 'calculatedbathnbr', 'roomcnt', 'heatingorsystemtypeid', 'buildingqualitytypeid', 'regionidneighborhood', 'calculatedfinishedsquarefeet_log', 'yearbuilt', 'lotsizesquarefeet', 'latitude', 'longitude', 'lotsizesquarefeet_log', 'bedroomcnt']
# Best CV Score: 34927023669.0331

# %%
backward_model = RandomForestRegressor(n_estimators = 100, n_jobs = -1, random_state = 42)

# %%
def backward_feature_selection(X, y, model, 
                               scoring='neg_mean_squared_error', 
                               cv=5, 
                               tol=None,
                               max_features=None,
                               n_jobs=-1,
                               verbose=True):
    def cv_score(features):
        return -cross_val_score(model, X[features], y, scoring=scoring, cv=cv, n_jobs=n_jobs).mean()

    features_remaining = list(X.columns)
    initial_score = cv_score(features_remaining)

    best_score_backward = initial_score
    best_feature_set_backward = features_remaining.copy()
    selected_features_backward = ['NONE']
    best_scores_backward = [initial_score]

    if verbose:
        print("Start with full set of features:")
        print(f'{features_remaining}  CV score (MSE): {np.around(initial_score, 4)}\n')

    target_feature_count = 1 if max_features is None else max_features
    prev_score = initial_score
    round_num = 1

    while len(features_remaining) > target_feature_count:
        if verbose:
            print(f'Round {round_num}:')

        lowest_score = float('inf')
        feature_to_remove = None
        best_new_features = None

        for feature in features_remaining:
            new_feature_set = features_remaining.copy()
            new_feature_set.remove(feature)
            new_score = cv_score(new_feature_set)
            if verbose:
                print('Trying removal of:', feature, np.around(new_score, 4))
            if new_score < lowest_score:
                lowest_score = new_score
                feature_to_remove = feature
                best_new_features = new_feature_set

        if tol is not None and (prev_score - lowest_score) < tol:
            if verbose:
                print("\nStopping early due to minimal improvement.")
            break

        if lowest_score < best_score_backward:
            best_score_backward = lowest_score
            best_feature_set_backward = best_new_features.copy()

        prev_score = lowest_score
        features_remaining = best_new_features
        selected_features_backward.append(feature_to_remove)
        best_scores_backward.append(lowest_score)

        if verbose:
            print(f'\nRemoving {feature_to_remove}:  CV score (MSE) {np.around(lowest_score, 4)}\n')
        round_num += 1

    return (
        selected_features_backward,
        best_scores_backward,
        best_feature_set_backward,
        best_score_backward
    )

# %%
selected_features_backward, best_scores_backward, best_feature_set_backward, best_score_backward = (
    backward_feature_selection(X, y, backward_model, verbose=True)
)

# Plot the results
plt.figure(figsize=(10, 6))
plt.title('Backward Feature Selection and CV Scores')
plt.plot(range(1, len(best_scores_backward) + 1), best_scores_backward, marker='.')
index = np.argmin(best_scores_backward)
plt.plot([index + 1], [best_scores_backward[index]], marker='x', color='red')
plt.xticks(range(1, len(selected_features_backward) + 1), selected_features_backward, rotation=40, ha='right', fontsize=8)
plt.xlabel('Features Removed')
plt.ylabel('CV Score (MSE)')
plt.grid()
plt.tight_layout()
plt.show()

# Print best backward selection results
print("Best feature set:", best_feature_set_backward)
print("CV score (MSE):", np.around(best_score_backward, 4))
# Out:
# Start with full set of features:
# ['bathroomcnt', 'bedroomcnt', 'buildingqualitytypeid', 'calculatedbathnbr', 'calculatedfinishedsquarefeet', 'finishedsquarefeet12', 'fips', 'fullbathcnt', 'heatingorsystemtypeid', 'latitude', 'longitude', 'lotsizesquarefeet', 'propertycountylandusecode', 'propertylandusetypeid', 'propertyzoningdesc', 'rawcensustractandblock', 'regionidcity', 'regionidcounty', 'regionidneighborhood', 'roomcnt', 'yearbuilt', 'lotsizesquarefeet_log', 'finishedsquarefeet12_log', 'calculatedfinishedsquarefeet_log']  CV score (MSE): 32470869768.6188
#
# Round 1:
# Trying removal of: bathroomcnt 32482678529.5074
# Trying removal of: bedroomcnt 32564570046.3451
# Trying removal of: buildingqualitytypeid 32544082443.7869
# Trying removal of: calculatedbathnbr 32497728690.7569
# Trying removal of: calculatedfinishedsquarefeet 32495664249.2068
# Trying removal of: finishedsquarefeet12 32482154391.5174
# Trying removal of: fips 32456486426.8451
# Trying removal of: fullbathcnt 32462995153.8385
# Trying removal of: heatingorsystemtypeid 32473798648.8873
# Trying removal of: latitude 32865001084.9722
# Trying removal of: longitude 32880696353.9491
# Trying removal of: lotsizesquarefeet 32469435596.6722
# Trying removal of: propertycountylandusecode 32527288020.0863
# Trying removal of: propertylandusetypeid 32482057496.2706
# Trying removal of: propertyzoningdesc 32463626575.9571
# Trying removal of: rawcensustractandblock 32484021698.1584
# Trying removal of: regionidcity 32530378734.0045
# Trying removal of: regionidcounty 32463944491.4025
# Trying removal of: regionidneighborhood 32420945015.3723
# Trying removal of: roomcnt 32507350293.4309
# Trying removal of: yearbuilt 33193204759.453
# Trying removal of: lotsizesquarefeet_log 32488867030.2546
# Trying removal of: finishedsquarefeet12_log 32486056235.8525
# Trying removal of: calculatedfinishedsquarefeet_log 32465820350.7305
#
# Removing regionidneighborhood:  CV score (MSE) 32420945015.3723
#
# Round 2:
# Trying removal of: bathroomcnt 32409325502.4809
# Trying removal of: bedroomcnt 32494074941.2038
# Trying removal of: buildingqualitytypeid 32521183593.6605
# Trying removal of: calculatedbathnbr 32408954980.315
# Trying removal of: calculatedfinishedsquarefeet 32419177098.281
# Trying removal of: finishedsquarefeet12 32413516236.7341
# Trying removal of: fips 32415442813.6188
# Trying removal of: fullbathcnt 32414292365.8273
# Trying removal of: heatingorsystemtypeid 32436040546.1377
# Trying removal of: latitude 32831759330.3318
# Trying removal of: longitude 32876048691.9113
# Trying removal of: lotsizesquarefeet 32434545299.9309
# Trying removal of: propertycountylandusecode 32486381012.0158
# Trying removal of: propertylandusetypeid 32414819093.6179
# Trying removal of: propertyzoningdesc 32433724662.0723
# Trying removal of: rawcensustractandblock 32470308733.6736
# Trying removal of: regionidcity 32469792031.0764
# Trying removal of: regionidcounty 32400634643.6156
# Trying removal of: roomcnt 32442096881.6636
# Trying removal of: yearbuilt 33161217774.218
# Trying removal of: lotsizesquarefeet_log 32406575802.7486
# Trying removal of: finishedsquarefeet12_log 32407922349.2442
# Trying removal of: calculatedfinishedsquarefeet_log 32421384916.8593
#
# Removing regionidcounty:  CV score (MSE) 32400634643.6156
#
# Round 3:
# Trying removal of: bathroomcnt 32420792723.3887
# Trying removal of: bedroomcnt 32514446156.943
# Trying removal of: buildingqualitytypeid 32509919793.2565
# Trying removal of: calculatedbathnbr 32416909362.2905
# Trying removal of: calculatedfinishedsquarefeet 32406261380.411
# Trying removal of: finishedsquarefeet12 32422650408.9163
# Trying removal of: fips 32429843599.7358
# Trying removal of: fullbathcnt 32426470510.4291
# Trying removal of: heatingorsystemtypeid 32436370103.667
# Trying removal of: latitude 32847434741.1126
# Trying removal of: longitude 32876905576.3451
# Trying removal of: lotsizesquarefeet 32399594021.8741
# Trying removal of: propertycountylandusecode 32483329603.3676
# Trying removal of: propertylandusetypeid 32419497226.5003
# Trying removal of: propertyzoningdesc 32440299898.3868
# Trying removal of: rawcensustractandblock 32459427421.9826
# Trying removal of: regionidcity 32497229091.7815
# Trying removal of: roomcnt 32439605856.6061
# Trying removal of: yearbuilt 33171164086.1095
# Trying removal of: lotsizesquarefeet_log 32426927266.3411
# Trying removal of: finishedsquarefeet12_log 32419187768.8342
# Trying removal of: calculatedfinishedsquarefeet_log 32417637393.9675
#
# Removing lotsizesquarefeet:  CV score (MSE) 32399594021.8741
#
# Round 4:
# Trying removal of: bathroomcnt 32454556722.651
# Trying removal of: bedroomcnt 32483257468.1614
# Trying removal of: buildingqualitytypeid 32519690319.5202
# Trying removal of: calculatedbathnbr 32403348590.4524
# Trying removal of: calculatedfinishedsquarefeet 32404984112.3117
# Trying removal of: finishedsquarefeet12 32403778628.333
# Trying removal of: fips 32436651456.0936
# Trying removal of: fullbathcnt 32422884394.0941
# Trying removal of: heatingorsystemtypeid 32448130679.4992
# Trying removal of: latitude 32842149063.8444
# Trying removal of: longitude 32884925328.8583
# Trying removal of: propertycountylandusecode 32481478999.0176
# Trying removal of: propertylandusetypeid 32437073444.5704
# Trying removal of: propertyzoningdesc 32450293471.5814
# Trying removal of: rawcensustractandblock 32462878268.8273
# Trying removal of: regionidcity 32469065847.7801
# Trying removal of: roomcnt 32438673247.6142
# Trying removal of: yearbuilt 33160744056.4197
# Trying removal of: lotsizesquarefeet_log 32909291631.6024
# Trying removal of: finishedsquarefeet12_log 32400596863.2457
# Trying removal of: calculatedfinishedsquarefeet_log 32415006057.9833
#
# Removing finishedsquarefeet12_log:  CV score (MSE) 32400596863.2457
#
# Round 5:
# Trying removal of: bathroomcnt 32430438384.4503
# Trying removal of: bedroomcnt 32497375675.7702
# Trying removal of: buildingqualitytypeid 32529569819.0895
# Trying removal of: calculatedbathnbr 32415530509.8758
# Trying removal of: calculatedfinishedsquarefeet 32408428462.4956
# Trying removal of: finishedsquarefeet12 32433739015.3848
# Trying removal of: fips 32411881236.7395
# Trying removal of: fullbathcnt 32420968135.8648
# Trying removal of: heatingorsystemtypeid 32433334893.5335
# Trying removal of: latitude 32854078401.3628
# Trying removal of: longitude 32888497728.141
# Trying removal of: propertycountylandusecode 32493716553.7704
# Trying removal of: propertylandusetypeid 32444513993.6304
# Trying removal of: propertyzoningdesc 32429538179.2572
# Trying removal of: rawcensustractandblock 32469318286.8644
# Trying removal of: regionidcity 32444796300.5157
# Trying removal of: roomcnt 32431452101.5497
# Trying removal of: yearbuilt 33178841910.5259
# Trying removal of: lotsizesquarefeet_log 32905139121.1676
# Trying removal of: calculatedfinishedsquarefeet_log 32399186586.8868
#
# Removing calculatedfinishedsquarefeet_log:  CV score (MSE) 32399186586.8868
#
# Round 6:
# Trying removal of: bathroomcnt 32429438186.1034
# Trying removal of: bedroomcnt 32464234036.1834
# Trying removal of: buildingqualitytypeid 32493461939.1423
# Trying removal of: calculatedbathnbr 32399542072.0683
# Trying removal of: calculatedfinishedsquarefeet 32506455761.5911
# Trying removal of: finishedsquarefeet12 32414998386.4218
# Trying removal of: fips 32409434325.495
# Trying removal of: fullbathcnt 32397389641.8213
# Trying removal of: heatingorsystemtypeid 32414640323.6062
# Trying removal of: latitude 32839717142.214
# Trying removal of: longitude 32874281171.9427
# Trying removal of: propertycountylandusecode 32495887867.3696
# Trying removal of: propertylandusetypeid 32400213152.1644
# Trying removal of: propertyzoningdesc 32440253782.4854
# Trying removal of: rawcensustractandblock 32460688514.2688
# Trying removal of: regionidcity 32441738233.27
# Trying removal of: roomcnt 32446569175.2987
# Trying removal of: yearbuilt 33157194981.2991
# Trying removal of: lotsizesquarefeet_log 32884187970.1573
#
# Removing fullbathcnt:  CV score (MSE) 32397389641.8213
#
# Round 7:
# Trying removal of: bathroomcnt 32406369778.6206
# Trying removal of: bedroomcnt 32489601077.8994
# Trying removal of: buildingqualitytypeid 32471928376.7245
# Trying removal of: calculatedbathnbr 32412462750.9878
# Trying removal of: calculatedfinishedsquarefeet 32522532168.36
# Trying removal of: finishedsquarefeet12 32431711207.2349
# Trying removal of: fips 32414836147.9256
# Trying removal of: heatingorsystemtypeid 32423785661.4036
# Trying removal of: latitude 32849472383.7092
# Trying removal of: longitude 32873939604.6806
# Trying removal of: propertycountylandusecode 32472812101.8196
# Trying removal of: propertylandusetypeid 32404297399.7629
# Trying removal of: propertyzoningdesc 32423480218.3584
# Trying removal of: rawcensustractandblock 32445053671.2607
# Trying removal of: regionidcity 32452072616.9162
# Trying removal of: roomcnt 32424735223.0308
# Trying removal of: yearbuilt 33162637778.4838
# Trying removal of: lotsizesquarefeet_log 32911947866.2758
#
# Removing propertylandusetypeid:  CV score (MSE) 32404297399.7629
#
# Round 8:
# Trying removal of: bathroomcnt 32414739942.499
# Trying removal of: bedroomcnt 32498175398.768
# Trying removal of: buildingqualitytypeid 32514725126.8546
# Trying removal of: calculatedbathnbr 32430985453.3859
# Trying removal of: calculatedfinishedsquarefeet 32538815082.7955
# Trying removal of: finishedsquarefeet12 32402425439.1292
# Trying removal of: fips 32398323232.5465
# Trying removal of: heatingorsystemtypeid 32437443130.4263
# Trying removal of: latitude 32840463665.469
# Trying removal of: longitude 32910069216.6866
# Trying removal of: propertycountylandusecode 32465011972.4887
# Trying removal of: propertyzoningdesc 32451173287.0972
# Trying removal of: rawcensustractandblock 32474187026.8072
# Trying removal of: regionidcity 32463889610.2238
# Trying removal of: roomcnt 32439442810.8689
# Trying removal of: yearbuilt 33184883692.8008
# Trying removal of: lotsizesquarefeet_log 32922616648.8674
#
# Removing fips:  CV score (MSE) 32398323232.5465
#
# Round 9:
# Trying removal of: bathroomcnt 32416580860.2391
# Trying removal of: bedroomcnt 32480706373.1633
# Trying removal of: buildingqualitytypeid 32507099994.919
# Trying removal of: calculatedbathnbr 32420790177.3009
# Trying removal of: calculatedfinishedsquarefeet 32537628044.6944
# Trying removal of: finishedsquarefeet12 32420968726.6539
# Trying removal of: heatingorsystemtypeid 32426893534.6136
# Trying removal of: latitude 32826253562.9047
# Trying removal of: longitude 32908573699.8924
# Trying removal of: propertycountylandusecode 32502056576.7071
# Trying removal of: propertyzoningdesc 32469730135.7976
# Trying removal of: rawcensustractandblock 32474218510.4061
# Trying removal of: regionidcity 32452608821.0262
# Trying removal of: roomcnt 32411641900.3977
# Trying removal of: yearbuilt 33200045811.4185
# Trying removal of: lotsizesquarefeet_log 32924491172.7412
#
# Removing roomcnt:  CV score (MSE) 32411641900.3977
#
# Round 10:
# Trying removal of: bathroomcnt 32427178970.6393
# Trying removal of: bedroomcnt 32527162387.9386
# Trying removal of: buildingqualitytypeid 32526886977.0003
# Trying removal of: calculatedbathnbr 32422192234.6263
# Trying removal of: calculatedfinishedsquarefeet 32556729475.6929
# Trying removal of: finishedsquarefeet12 32443704280.9306
# Trying removal of: heatingorsystemtypeid 32453315341.215
# Trying removal of: latitude 32895697906.9328
# Trying removal of: longitude 32908103109.8669
# Trying removal of: propertycountylandusecode 32511581502.7899
# Trying removal of: propertyzoningdesc 32472988434.4047
# Trying removal of: rawcensustractandblock 32492940982.4111
# Trying removal of: regionidcity 32475677414.8408
# Trying removal of: yearbuilt 33300289225.6564
# Trying removal of: lotsizesquarefeet_log 32948956304.401
#
# Removing calculatedbathnbr:  CV score (MSE) 32422192234.6263
#
# Round 11:
# Trying removal of: bathroomcnt 32564761508.6483
# Trying removal of: bedroomcnt 32528229259.4116
# Trying removal of: buildingqualitytypeid 32545701887.3636
# Trying removal of: calculatedfinishedsquarefeet 32552206479.9473
# Trying removal of: finishedsquarefeet12 32439453431.0007
# Trying removal of: heatingorsystemtypeid 32438935023.9394
# Trying removal of: latitude 32901458748.8306
# Trying removal of: longitude 32921161756.0389
# Trying removal of: propertycountylandusecode 32507315709.5366
# Trying removal of: propertyzoningdesc 32482062669.0967
# Trying removal of: rawcensustractandblock 32500038903.6624
# Trying removal of: regionidcity 32469671775.7429
# Trying removal of: yearbuilt 33304503492.8228
# Trying removal of: lotsizesquarefeet_log 32959794811.2182
#
# Removing heatingorsystemtypeid:  CV score (MSE) 32438935023.9394
#
# Round 12:
# Trying removal of: bathroomcnt 32602453521.9553
# Trying removal of: bedroomcnt 32549717467.8069
# Trying removal of: buildingqualitytypeid 32598988230.333
# Trying removal of: calculatedfinishedsquarefeet 32584071783.9458
# Trying removal of: finishedsquarefeet12 32453324926.9812
# Trying removal of: latitude 32923541855.2166
# Trying removal of: longitude 32945663776.6103
# Trying removal of: propertycountylandusecode 32538312014.9555
# Trying removal of: propertyzoningdesc 32516815313.4192
# Trying removal of: rawcensustractandblock 32543515288.5825
# Trying removal of: regionidcity 32497572233.5948
# Trying removal of: yearbuilt 33303148176.1282
# Trying removal of: lotsizesquarefeet_log 32977991706.9109
#
# Removing finishedsquarefeet12:  CV score (MSE) 32453324926.9812
#
# Round 13:
# Trying removal of: bathroomcnt 32553521770.0158
# Trying removal of: bedroomcnt 32547017554.3306
# Trying removal of: buildingqualitytypeid 32651115028.9995
# Trying removal of: calculatedfinishedsquarefeet 33993344109.0711
# Trying removal of: latitude 32982858823.9836
# Trying removal of: longitude 32897367799.1994
# Trying removal of: propertycountylandusecode 32593448778.0538
# Trying removal of: propertyzoningdesc 32390267181.1911
# Trying removal of: rawcensustractandblock 32477504782.0539
# Trying removal of: regionidcity 32454517275.7017
# Trying removal of: yearbuilt 33258948691.479
# Trying removal of: lotsizesquarefeet_log 33017916500.2481
#
# Removing propertyzoningdesc:  CV score (MSE) 32390267181.1911
#
# Round 14:
# Trying removal of: bathroomcnt 32545274515.6278
# Trying removal of: bedroomcnt 32490903260.5786
# Trying removal of: buildingqualitytypeid 32620775910.5756
# Trying removal of: calculatedfinishedsquarefeet 34026386202.5698
# Trying removal of: latitude 32997729643.2315
# Trying removal of: longitude 32893047722.2609
# Trying removal of: propertycountylandusecode 32533527659.2076
# Trying removal of: rawcensustractandblock 32450760005.4393
# Trying removal of: regionidcity 32472528331.2995
# Trying removal of: yearbuilt 33283177613.1954
# Trying removal of: lotsizesquarefeet_log 33018319725.669
#
# Removing rawcensustractandblock:  CV score (MSE) 32450760005.4393
#
# Round 15:
# Trying removal of: bathroomcnt 32608010709.0975
# Trying removal of: bedroomcnt 32539515130.2324
# Trying removal of: buildingqualitytypeid 32605036300.3149
# Trying removal of: calculatedfinishedsquarefeet 34130328909.397
# Trying removal of: latitude 34070025710.493
# Trying removal of: longitude 33480683727.2574
# Trying removal of: propertycountylandusecode 32596850045.6737
# Trying removal of: regionidcity 32503759031.093
# Trying removal of: yearbuilt 33393734371.5984
# Trying removal of: lotsizesquarefeet_log 33068508510.5901
#
# Removing regionidcity:  CV score (MSE) 32503759031.093
#
# Round 16:
# Trying removal of: bathroomcnt 32641762641.1159
# Trying removal of: bedroomcnt 32557628319.9059
# Trying removal of: buildingqualitytypeid 32615176795.4166
# Trying removal of: calculatedfinishedsquarefeet 34104879370.6864
# Trying removal of: latitude 35156582250.58
# Trying removal of: longitude 34070297959.6849
# Trying removal of: propertycountylandusecode 32660370776.4079
# Trying removal of: yearbuilt 33413511080.9247
# Trying removal of: lotsizesquarefeet_log 33145032064.6096
#
# Removing bedroomcnt:  CV score (MSE) 32557628319.9059
#
# Round 17:
# Trying removal of: bathroomcnt 32728499951.8641
# Trying removal of: buildingqualitytypeid 32716375848.2228
# Trying removal of: calculatedfinishedsquarefeet 34475203406.2364
# Trying removal of: latitude 35268128533.974
# Trying removal of: longitude 34225695663.5457
# Trying removal of: propertycountylandusecode 32712462091.4588
# Trying removal of: yearbuilt 33498462432.1343
# Trying removal of: lotsizesquarefeet_log 33233995711.3361
#
# Removing propertycountylandusecode:  CV score (MSE) 32712462091.4588
#
# Round 18:
# Trying removal of: bathroomcnt 32859262694.8647
# Trying removal of: buildingqualitytypeid 32900565626.3441
# Trying removal of: calculatedfinishedsquarefeet 34945916094.9002
# Trying removal of: latitude 35697596113.9564
# Trying removal of: longitude 34508138727.8905
# Trying removal of: yearbuilt 33808031623.6381
# Trying removal of: lotsizesquarefeet_log 33423494252.2019
#
# Removing bathroomcnt:  CV score (MSE) 32859262694.8647
#
# Round 19:
# Trying removal of: buildingqualitytypeid 33076288158.7596
# Trying removal of: calculatedfinishedsquarefeet 36698809115.8027
# Trying removal of: latitude 35945729412.2558
# Trying removal of: longitude 34750818960.8029
# Trying removal of: yearbuilt 34072633981.742
# Trying removal of: lotsizesquarefeet_log 33599864435.2016
#
# Removing buildingqualitytypeid:  CV score (MSE) 33076288158.7596
#
# Round 20:
# Trying removal of: calculatedfinishedsquarefeet 37307855117.9643
# Trying removal of: latitude 37117138265.6304
# Trying removal of: longitude 35722253945.2441
# Trying removal of: yearbuilt 34327099662.7954
# Trying removal of: lotsizesquarefeet_log 33795430532.0997
#
# Removing lotsizesquarefeet_log:  CV score (MSE) 33795430532.0997
#
# Round 21:
# Trying removal of: calculatedfinishedsquarefeet 38853611241.2464
# Trying removal of: latitude 39424436991.7137
# Trying removal of: longitude 37683474062.169
# Trying removal of: yearbuilt 35494669572.4055
#
# Removing yearbuilt:  CV score (MSE) 35494669572.4055
#
# Round 22:
# Trying removal of: calculatedfinishedsquarefeet 41425268922.1841
# Trying removal of: latitude 44626137285.6868
# Trying removal of: longitude 43304272066.8181
#
# Removing calculatedfinishedsquarefeet:  CV score (MSE) 41425268922.1841
#
# Round 23:
# Trying removal of: latitude 67943504868.6846
# Trying removal of: longitude 66964924083.0051
#
# Removing longitude:  CV score (MSE) 66964924083.0051
# Best feature set: ['bathroomcnt', 'bedroomcnt', 'buildingqualitytypeid', 'calculatedfinishedsquarefeet', 'latitude', 'longitude', 'propertycountylandusecode', 'rawcensustractandblock', 'regionidcity', 'yearbuilt', 'lotsizesquarefeet_log']
# CV score (MSE): 32390267181.1911

# %% [markdown]
# #### **4.A Discussion:**  Describe in a paragraph what you see in the feature relationships and correlations.
#
# Pay particular attention to especially interesting and/or strongly correlated feature relationships.
#  How do the different methods for seeing relationships compare? Do they agree or disagree?
#
# Based on the strategies utilized like using the correlation matrix heatmap, f-score analysis, and the features selection, we found that all of the analysis had a similar output results of having bedroom count to be the feature that has higher significance in the model and all of the tested strategies mentioned confirms the feature significance. The f-score analysis determines whether some independent variables explain a significant amount of variance in the dependent variable so we can see that there is a significance of finished square feet to be an indicator of such variance. Whereas we have the correlation matrix it has a 0.6 or 60% correlation for the bedroom count. And then using the forward feature selection based on the cross validation values we see that it also points that bed room count was selected having the number of estimators to be around 100.

# %% [markdown]
# ### Part 4.B:  2-Dimensional Visualizations for Interesting Patterns
#    - Select three (3) pairs of features that exhibit meaningful relationships based on your previous analysis.
#    - Create 2D scatter plots or density plots to explore interactions between these features.
#    - Provide brief interpretations of any observed patterns or trends.

# %%
plt.figure(figsize = (12, 15))
plt.subplot(3, 1, 1)
plt.scatter(X["bedroomcnt"], X["finishedsquarefeet12"])
plt.title("Bed Count vs. Finished Sq Feet 12")
plt.xlabel("Bedroom Count")
plt.ylabel("Finsihed Square Feet 12")

plt.subplot(3, 1, 2)
plt.scatter(X["calculatedfinishedsquarefeet"], X["calculatedbathnbr"])
plt.title("Finished Square Feet vs. Bathroom Number")
plt.xlabel("calculatedfinishedsquarefeet")
plt.ylabel("calculatedbathroomnbr")

plt.subplot(3, 1, 3)
plt.scatter(X["buildingqualitytypeid"], X["finishedsquarefeet12"])
plt.title("Build Quality Type ID vs. Finished Square Feet 12")
plt.xlabel("Build Quality Type ID")
plt.ylabel("Finished Square Feet 12")

plt.tight_layout()
plt.show()

# %% [markdown]
# #### **4.B Discussion:** Provide brief interpretations of any observed patterns or trends.
#
# The relationship between bedroom count and finished square feet shows a clear upward trend, indicating that homes with more bedrooms generally contain more finished square footage. This graph does also come with increasing variance: As bedroom count increases from 1 to 8, the variance in sqft increases significantly. Homes with 7 or 8 bed homes range anywhere from ~1,500 sqft up to 8,000 sqft. We also noted that above  6 bedrooms, the increase in square footage per additional bedroom diminishes as the slope of the trend flattens. This suggests that while more bedrooms typically correlate with more finished square footage (aka larger homes), the incremental size gain tapes off at the high end, even though some luxury properties continue to push the upper limits of square footage.
# Next, the relationship between finished square feet and bathroom number shows a positive correlation. Homes with more bathrooms tend to come with more living area. Homes with 3 or fewer bathrooms cluster below
# 2,500 sqft while homes with 4-6 baths often exceed 3,000 sqft. We noted that the relationship is less discrete, because bathrooms can include half-baths or odd counts such as 1.5, or 2.5, the relationship looks more complex than pure bedroom counts, but overall it tracks very closely with size. There does tend to be wider overlap at mid-sizes. When looking at homes with 2.5-4 bathrooms, homes of 2,000-5,000 sqft all intermingle, showing that bathroom count alone doesn't help pinpoint the size of a home as precisely as bedrooms do.
# When examining the relationship between build quality type id and finished square feet, we found a generally upward trend, though containing much more noise. Higher build quality skew towards larger homes, but each quality band still spans a wide range of sizes. Because the quality rating is an ordinal integer, the plot shows distinct vertical groupings: lower quality IDs such as 1-3 rarely exceed 2,000 sqft, while higher quality IDs such as 6-12 often range from 4,000 - 7,000 sqft. Despite this trend, there is overlap across quality levels. Some top quality homes are modestly sized, making build quality a weaker predictor of size than bath or bedroom count.

# %% [markdown]
# ## Part 5:  Feature Engineering: Investigate various transformations to better expose the underlying data patterns to machine learning algorithms. [6 pts]
#
# **Important Notes:**
# - This last part is a bit open ended, since there is a huge variety of feature engineering techniques, most of which won't be useful for your particular dataset.
# - Understand that you can't evaluate the final usefulness of these transformations
# until you choose a model, and  models may respond differently to various transformations or obviate some transformations (e.g., ensemble methods already do feature selection).
# - Therefore, write your transformations as functions or otherwise be prepared
# to choose later on which transformations may be necessary.
#
# **Investigate feature engineering, where appropriate:**
#
# - Feature scaling: standardize or normalize features as necessary
# - Decompose features (e.g., categorical into One-Hot feature sequence, date/time into two features data and time, etc.).
# - Add promising transformations of features
#     - Exponential $\exp(x_i)$ or logarithmic $\log(x_j)$
#     - Polynomial features  ( $x_i^2$, $x_i - x_j$), products ($x_i*x_j$), or ratios ($x_i/x_j$)
#
# **ToDo:**
# - Pick at least three transformations to try.
# - Try each one and evaluate its effect using correlations or F-scores or a feature selection algorithm.
# - Answer the discussion question.

# %%
one_hot = pd.get_dummies(X, columns = ["fullbathcnt", "bedroomcnt"]).astype(int)

selector = SelectKBest(score_func = f_regression, k=10)
X_selected = selector.fit_transform(one_hot, y)
one_hot_selected = one_hot.columns[selector.get_support()]
print(one_hot_selected)
# Out:
# Index(['bathroomcnt', 'buildingqualitytypeid', 'calculatedbathnbr',
#        'calculatedfinishedsquarefeet', 'finishedsquarefeet12', 'latitude',
#        'yearbuilt', 'fullbathcnt_1.0', 'fullbathcnt_3.0', 'fullbathcnt_4.0'],
#       dtype='object')

# %%
#Standardization
#Load or define your DataFrame
#Select the numeric columns you want to standardized
numeric_cols = X.select_dtypes(include=[np.number]).columns.tolist()
#Initialize the StandardScaler
scaler = StandardScaler()
#Fit the scaler on your numeric data and transform it
df_scaled = X.copy()
df_scaled[numeric_cols] = scaler.fit_transform(X[numeric_cols])
#Check the result
print(df_scaled)
#Feature Selector
# X_standardized = df_scaled.drop("taxvaluedollarcnt", axis=1).copy()
# y_standardized = df_scaled["taxvaluedollarcnt"]
selector = SelectKBest(score_func=f_regression, k=10)
X_new = selector.fit_transform(df_scaled,y)
standardized_selected_features = X.columns[selector.get_support()]
print(standardized_selected_features)
# Out:
#        bathroomcnt  bedroomcnt  buildingqualitytypeid  calculatedbathnbr  \
# 0         1.519451    0.910911              -0.197606           1.538840
# 1        -1.392409   -0.899855              -0.197606          -1.442312
# 2        -0.227665    0.005528              -0.197606          -0.249851
# 3         0.937079    0.910911               1.308905           0.942609
# 4         0.937079    0.005528               1.308905           0.942609
# ...            ...         ...                    ...                ...
# 77608     0.937079    0.005528               1.308905           0.942609
# 77609    -0.227665   -0.899855              -0.197606          -0.249851
# 77610    -0.227665    0.910911              -0.197606          -0.249851
# 77611    -1.392409    0.005528              -1.704116          -1.442312
# 77612    -0.227665    0.005528              -0.197606          -0.249851
#
#        calculatedfinishedsquarefeet  finishedsquarefeet12      fips  \
# 0                          1.990154              2.164806  0.480860
# 1                         -0.271197             -0.236024  2.962622
# 2                         -0.578243             -0.562008  0.480860
# 3                          0.988797              1.101686 -0.569116
# 4                         -0.482809             -0.460689 -0.569116
# ...                             ...                   ...       ...
# 77608                      0.110536              0.169254 -0.569116
# 77609                     -0.518770             -0.498867 -0.569116
# 77610                     -0.067883             -0.020170  2.962622
# 77611                     -0.870074             -0.871840 -0.569116
# 77612                      0.139581              0.200090 -0.569116
#
#        fullbathcnt  heatingorsystemtypeid  latitude  ...  lotsizesquarefeet  \
# 0         1.022603              -0.417827 -1.421610  ...          -0.196258
# 1        -1.377639              -0.417827  1.632153  ...          -0.128244
# 2        -0.177518              -0.417827 -0.479469  ...          -0.163458
# 3         1.022603              -0.417827  0.866829  ...          -0.124978
# 4         1.022603              -0.417827  0.641604  ...           2.093475
# ...            ...                    ...       ...  ...                ...
# 77608     1.022603              -0.417827  0.706404  ...           0.263076
# 77609    -0.177518              -0.417827  0.867534  ...           0.162138
# 77610    -0.177518              -0.417827  1.072930  ...          -0.132772
# 77611    -1.377639              -0.417827  0.100759  ...          -0.191512
# 77612    -0.177518              -0.417827 -0.286280  ...          -0.180877
#
#        propertycountylandusecode  propertylandusetypeid  propertyzoningdesc  \
# 0                       1.314171              -0.174210           -0.430877
# 1                       0.941460              -0.174210           -0.430877
# 2                       1.314171              -0.174210           -0.430877
# 3                      -0.839268              -0.174210            0.112585
# 4                      -0.549382               0.806019           -0.412137
# ...                          ...                    ...                 ...
# 77608                  -0.549382               0.806019           -0.382688
# 77609                  -0.880680              -0.174210           -0.358594
# 77610                   0.982872              -0.174210           -0.430877
# 77611                  -0.880680              -0.174210            2.232891
# 77612                  -0.880680              -0.174210            2.853991
#
#        rawcensustractandblock  regionidcity  regionidcounty  \
# 0                    0.472555      0.413790       -1.565143
# 1                    2.970286     -0.433747       -0.595490
# 2                    0.470574     -0.259529       -1.565143
# 3                   -0.574037      7.594824        0.705723
# 4                   -0.582525     -0.447231        0.705723
# ...                       ...           ...             ...
# 77608               -0.582125     -0.447231        0.705723
# 77609               -0.583592     -0.447231        0.705723
# 77610                2.970642     -0.140229       -0.595490
# 77611               -0.567607      0.056413        0.705723
# 77612               -0.564260     -0.401441        0.705723
#
#        regionidneighborhood   roomcnt  yearbuilt
# 0                 -0.248956 -0.531256   1.276347
# 1                 -0.248956  1.247213  -0.051773
# 2                 -0.248956  1.602907  -0.265986
# 3                 -0.248956 -0.531256   0.076755
# 4                  1.138693 -0.531256  -0.180301
# ...                     ...       ...        ...
# 77608             -1.050600 -0.531256   0.505181
# 77609             -1.097319 -0.531256  -1.208523
# 77610             -0.248956  1.958601  -0.180301
# 77611             -0.248956 -0.531256  -0.608727
# 77612             -0.248956 -0.531256  -0.565884
#
# [72392 rows x 21 columns]
# Index(['bathroomcnt', 'bedroomcnt', 'buildingqualitytypeid',
#        'calculatedbathnbr', 'calculatedfinishedsquarefeet',
#        'finishedsquarefeet12', 'fullbathcnt', 'heatingorsystemtypeid',
#        'latitude', 'yearbuilt'],
#       dtype='object')

# %%
log_features = [
    'lotsizesquarefeet',
    'finishedsquarefeet12',
    'calculatedfinishedsquarefeet'
]

# Apply log1p transformation to multiple features
for col in log_features:
    X[col] = X[col].fillna(0)  # Fill missing values to avoid log(0) errors
    X[col + '_log'] = np.log1p(X[col])  # Compute log(1 + x)

# %%
selector = SelectKBest(score_func = f_regression, k=10)
X_selected = selector.fit_transform(X, y)
log_selected_features = X.columns[selector.get_support()]
print(log_selected_features)
# Out:
# Index(['bathroomcnt', 'bedroomcnt', 'buildingqualitytypeid',
#        'calculatedbathnbr', 'calculatedfinishedsquarefeet',
#        'finishedsquarefeet12', 'fullbathcnt', 'yearbuilt',
#        'finishedsquarefeet12_log', 'calculatedfinishedsquarefeet_log'],
#       dtype='object')

# %% [markdown]
# #### **5 Discussion:** Describe in a paragraph why you chose these transformations and what you observed.
#
# We applied three feature engineering techniques to prepare the Zillow dataset: one-hot encoding, log transformation, and standardization. One-hot encoding was necessary for categorical features like property type to convert them into a machine-readable format without implying ordinal relationships. Log transformation was applied to the financial features to address their right-skewed distribution, which improved their correlation with the target variable and helped reduce the dominance of extreme values. Lastly, standardization ensured that numeric features like square footage and number of bedrooms contributed equally during model training, particularly benefiting algorithms sensitive to feature scales.

# %% [markdown]
# ## **Appendix 1: Features of the Zillow Dataset**
#
# 0. **parcelid**: Unique identifier for the property parcel.
# 1. **airconditioningtypeid**: Identifier for the type of air conditioning installed.
# 2. **architecturalstyletypeid**: Identifier for the architectural style of the property.
# 3. **basementsqft**: Square footage of the basement.
# 4. **bathroomcnt**: Number of bathrooms.
# 5. **bedroomcnt**: Number of bedrooms.
# 6. **buildingclasstypeid**: Identifier for the building framing type (e.g., wood frame, steel frame).
# 7. **buildingqualitytypeid**: Numeric value indicating the quality of the building (higher values often indicate better quality).
# 8. **calculatedbathnbr**: Calculated number of bathrooms, including fractional bathrooms.
# 9. **decktypeid**: Identifier for the type of deck.
# 10. **finishedfloor1squarefeet**: Square footage of the finished area on the first floor.
# 11. **calculatedfinishedsquarefeet**: Total finished living area square footage.
# 12. **finishedsquarefeet12**: Finished living area square footage.
# 13. **finishedsquarefeet13**: Perimeter living area square footage.
# 14. **finishedsquarefeet15**: Total area.
# 15. **finishedsquarefeet50**: Square footage of the finished area on the upper floors.
# 16. **finishedsquarefeet6**: Base unfinished and finished area square footage.
# 17. **fips**: Federal Information Processing Standards code, uniquely identifying counties and county equivalents.
# 18. **fireplacecnt**: Number of fireplaces.
# 19. **fullbathcnt**: Number of full bathrooms.
# 20. **garagecarcnt**: Number of cars that can fit in the garage.
# 21. **garagetotalsqft**: Total square footage of the garage.
# 22. **hashottuborspa**: Indicates if the property has a hot tub or spa.
# 23. **heatingorsystemtypeid**: Identifier for the type of heating system.
# 24. **latitude**: Latitude coordinate of the property.
# 25. **longitude**: Longitude coordinate of the property.
# 26. **lotsizesquarefeet**: Lot size in square feet.
# 27. **poolcnt**: Number of pools on the property.
# 28. **poolsizesum**: Total square footage of all pools.
# 29. **pooltypeid10**: Identifier for spa or hot tub.
# 30. **pooltypeid2**: Identifier for pool with spa or hot tub.
# 31. **pooltypeid7**: Identifier for pool without hot tub or spa.
# 32. **propertycountylandusecode**: County land use code for the property.
# 33. **propertylandusetypeid**: Identifier for the property land use type.
# 34. **propertyzoningdesc**: Description of the property's zoning.
# 35. **rawcensustractandblock**: Unprocessed census tract and block identifier.
# 36. **regionidcity**: Identifier for the city.
# 37. **regionidcounty**: Identifier for the county.
# 38. **regionidneighborhood**: Identifier for the neighborhood.
# 39. **regionidzip**: Identifier for the ZIP code.
# 40. **roomcnt**: Total number of rooms.
# 41. **storytypeid**: Identifier for the type of stories in the building (e.g., basement, attic).
# 42. **threequarterbathnbr**: Number of 3/4 bathrooms (typically includes a shower but no tub).
# 43. **typeconstructiontypeid**: Identifier for the type of construction (e.g., frame, masonry).
# 44. **unitcnt**: Number of units in the building (e.g., for multi-family properties).
# 45. **yardbuildingsqft17**: Square footage of the 17th yard building (e.g., shed).
# 46. **yardbuildingsqft26**: Square footage of the 26th yard building.
# 47. **yearbuilt**: Year the property was built.
# 48. **numberofstories**: Number of stories in the building.
# 49. **fireplaceflag**: Indicates if the property has a fireplace.
# 50. **assessmentyear**: Year the property was assessed.
# 51. **taxdelinquencyflag**: Indicates whether the property’s taxes are delinquent. Often “Y” if taxes are past due; otherwise null/empty.
# 52. **taxdelinquencyyear**: The year in which the property’s taxes became delinquent.
# 53. **censustractandblock**: A combined identifier for the property’s census tract and block group (part of the U.S. Census geographic hierarchy).
# 54. **taxvaluedollarcnt**: Total assessed value of the property (land plus structure) in dollars.

# %% [markdown]
# ## Appendix 2: Summary of Basic Imputation Methods
# Imputation depends on the data type and context. Below are common techniques for handling missing values.
#
# ---
#
# ### **1. Simple Imputation (Basic Methods)**
# | Method | Best For | Code Example | Pros | Cons |
# |--------|---------|--------------|------|------|
# | **Drop Missing Values** | Few missing values (<5% of data) | `df.dropna()` | Quick and easy | Can remove valuable data |
# | **Mean Imputation** | Normally distributed numerical data | `df.fillna(df.mean())` | Preserves mean; simple | Distorts variance, weak for skewed data |
# | **Median Imputation** | Skewed numerical data | `df.fillna(df.median())` | Robust to outliers | May not capture patterns |
# | **Mode Imputation** | Categorical features | `df.fillna(df.mode().iloc[0])` | Keeps most common category | Can introduce bias |
# | **Constant Value (e.g., 0)** | Special cases (e.g., unknown numerical data) | `df.fillna(0)` | Simple and interpretable | Can mislead model |
# | **"Unknown" Category Imputation** (**New Addition**) | Categorical features with missing values | `df.fillna('Unknown')` | Keeps all rows, prevents data loss | May introduce artificial category |
#
# ---
#
# ### **2. Statistical & Advanced Imputation**
# | Method | Best For | Code Example | Pros | Cons |
# |--------|---------|--------------|------|------|
# | **Interpolation** | Time series, ordered data | `df.interpolate(method='linear')` | Preserves trends | May not work for non-continuous data |
# | **K-Nearest Neighbors (KNN)** | Small datasets, patterns in features | `KNNImputer(n_neighbors=5).fit_transform(df)` | Uses similar observations | Computationally expensive |
# | **Multivariate Imputation (MICE)** | Complex relationships between variables | `IterativeImputer().fit_transform(df)` | Captures relationships | Slower than mean/median |
# | **Regression Imputation** | When missing values depend on other variables | Train regression model to predict missing values | More accurate than mean/median | Risk of overfitting |
#
# ---
#
# ### **When to Use "Unknown" Category for Categorical Imputation**
# ✅ **Good for:**
# - Categorical features where missing values may indicate meaningful differences.
# - Customer data (e.g., missing survey responses → "No Response").
# - Product categories where missing could be a separate group.
#
# ❌ **Avoid if:**
# - The missing category does **not** have a meaningful interpretation.
# - The model might learn spurious patterns from an artificial category.
#
# ---
#
# ### **Which Method to Choose?**
# | Scenario | Best Method |
# |----------|------------|
# | **Few missing values (<5%)** | Drop NaNs (`df.dropna()`) |
# | **Numerical & normal distribution** | Mean (`df.fillna(df.mean())`) |
# | **Numerical & skewed distribution** | Median (`df.fillna(df.median())`) |
# | **Categorical features** | Mode (`df.fillna(df.mode().iloc[0])`) |
# | **Categorical with possible meaning in missingness** | "Unknown" Category (`df.fillna('Unknown')`) |
# | **Small dataset with patterns** | KNN Imputer (`KNNImputer()`) |
# | **Complex relationships between features** | MICE / Iterative Imputer |
