# %% [markdown]
# # **Week 5: Feature Selection and Regularization on the Ames Housing Dataset**
#
# In this homework, we will experiment with two feature selection methods and one regularization technique for linear regression:
# - **Forward Selection**
# - **Backward Selection**
# - **Ridge Regression**
#
# We will apply these techniques to the preprocessed Ames Housing dataset from last week, evaluate which method achieves the best cross-validation (CV) score, and provide a final test score for the best model.
#
# There are 4 problems with 8 graded answers worth 6 points each, and you get 2 points free.

# %%
# Useful imports

import os
import kagglehub
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
import io
import zipfile

from sklearn.model_selection   import train_test_split, cross_val_score,RepeatedKFold
from sklearn.linear_model      import LinearRegression,Ridge,Lasso
from sklearn.model_selection   import GridSearchCV
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.metrics           import mean_squared_error, r2_score
from sklearn.preprocessing     import StandardScaler 

random_seed = 42

# %% [markdown]
# ## **Prelude: Download the Preprocessed Ames Housing Dataset**
#
# I have stored the dataset as a zipped directory containing the following four files from an 80%-20% split of the Ames dataset after preprocessing (as done in the last homework):
#
# - `X_train.csv`
# - `y_train.csv`
# - `X_test.csv`
# - `y_test.csv`
#
# **TODO:** Run the following cell to download and extract the dataset into the current working directory of this notebook.
# Alternatively, you can manually download the zip file from the provided URL, extract it, and place the files in the same directory as your notebook.
#
# > ⚠️ **Important:**
# > DO NOT use your own version of these datasets from the last homework. The autograder expects the exact split provided in my files for both training and testing sets. Using any other split will result in incorrect results during grading.

# %%
# Download the Ames Housing Dataset from Snyder's web site

# URL to the zip file
zip_url = "https://www.cs.bu.edu/fac/snyder/cs505/Data/ames_housing.zip"

try:
    response = requests.get(zip_url)
    response.raise_for_status()  # Raise an error for bad status codes
    with zipfile.ZipFile(io.BytesIO(response.content)) as zipf:
        zipf.extractall("ames_data")
    print("Files downloaded and extracted successfully.")
except requests.exceptions.RequestException as e:
    print(f"Error downloading the file: {e}")

# Load the datasets
X_train = pd.read_csv("ames_data/X_train.csv")
X_test = pd.read_csv("ames_data/X_test.csv")
y_train = pd.read_csv("ames_data/y_train.csv").squeeze("columns")          # converted to a Series
y_test = pd.read_csv("ames_data/y_test.csv").squeeze("columns")

print("Training and testing datasets loaded successfully.")
# Out:
# Files downloaded and extracted successfully.
# Training and testing datasets loaded successfully.

# %% [markdown]
# ## **Problem One: Forward Selection with the Ames Dataset**
#
# For our first experiment we will apply the forward feature selection algorithm to the dataset. Follow these steps, using the notebook from this week's video lesson as a resource as necessary.
#
# **If you have not looked at the video yet, please do it now before continuing.**
#
# **Steps to Follow:**
# 1. **Observe** that we have provided the `forward_feature_selection` algorithm from the video notebook for you to use.
#
# 2. **Copy** from the video notebook into the cell indicated below the code that runs forward feature selection and generates a plot (excluding the part that prints the test MSE--we'll do that at the end of this homework). Or write your own version!
#
# 3. **Modify** this code to display the **Root Mean Squared Error (RMSE)** instead of MSE.
#    - *Remember*: RMSE is the square root of MSE, which provides results in dollars rather than dollars squared, making the metric more interpretable.
#    - Both the plot of RMSE vs. the number of selected features and the printout of the Best CV Score should use RMSE.
#
# 4. **Run** the code on `X_train` and `y_train` (keeping all default settings) to:
#    - Generate the plot of **Root Mean Squared Error (RMSE)** vs. **Features Added**, and
#    - Print the **Best Feature Set** found and the **Best CV RMSE Score**.
#
# **Hints:**
# - The feature names will be more legible if you increase the size of the plot and change the angle and size of the xticks, e.g.,
#
#         plt.xticks(range(1, len(selected_features_forward) + 1), selected_features_forward, rotation=60, ha='right', fontsize=6)
#
# - You may wish to change the scale of the y-axis to better see the behavior around the minimum point.

# %%
# Forward Feature Selection
#Feature selection is in which you have to be selective and how much a feature contributes to the dataset
#take subset of all features. Like every possible combination of features is not as useful
#Use greedy method either start backward like starting with all features then select the features that are best 
#Forward method start with no features then every single feature combination would give the best model. Keep adding usually there is a number of informative features. Then there is a break even point.
#In most cases the backwards method works the best. If reduces the number of features its easy to anlayze the data.
#Prevent memorize the data (prevent generalize but finding the best one)
#model is the coefficients
#Lasso can zero out the coefficient good for enormous numbers of features. Forward and backward selection.
#X and y is the training set, there is default paramters like scoring, cv, tol. 
#If machine has parallelism and multiple cores then there is n_jobs is the number of instances of code running
# for the n_jobs it will take all possible -1 depending how many cores are avavilable.
#
def forward_feature_selection(X, y, model, 
                              scoring='neg_mean_squared_error', 
                              cv = 5, 
                              tol=None,               # None = no delta cutoff
                                                      # use 0.0 for "no further improvements"
                                                      # and 1e-4 for "point of diminishing returns"                                      
                              max_features=None,      # None = use all features
                              n_jobs=-1,
                              verbose=False
                             ):
    selected_features = []                            # List to store the order of features selected
    remaining_features = list(X.columns)              # Features not yet selected
    best_scores = []                                  # List to store the CV score after each feature addition
    previous_score = float('inf')                     # Initialize previous score for improvement comparison

    # Track the best subset of features and its corresponding score
    
    best_feature_set = None                           # Best combination of features found so far
    best_score = float('inf')                         # Best CV score observed so far
    
    while remaining_features:
        scores = {}                                   # Dictionary to hold CV scores for each candidate feature
        for feature in remaining_features:
            current_features = selected_features + [feature]
            
            # Compute the CV score for the current set of features (negated MSE, so lower is better)
            cv_score = -cross_val_score(model, X[current_features], y, 
                                        scoring=scoring, cv=cv, n_jobs=n_jobs
                                       ).mean()
            scores[feature] = cv_score

        # Select the feature that minimizes the CV score
        best_feature = min(scores, key=scores.get)
        current_score = scores[best_feature]
            
        # Check if the improvement is significant based on the tolerance (tol)
        if tol is not None and previous_score - current_score < tol:
            if verbose:
                print("Stopping early due to minimal improvement.")
            break

        # Add the best feature to the selected list and update score trackers
        selected_features.append(best_feature)
        best_scores.append(current_score)
        remaining_features.remove(best_feature)
        previous_score = current_score

        if verbose:
            print(f"\nFeatures: {selected_features[-3:]}, CV Score (MSE): {current_score:.4f}")
        
        # Update the best subset if the current score is better than the best so far
        if current_score < best_score:
            best_score = current_score
            best_feature_set = selected_features.copy()
        
        # Check if the maximum number of features has been reached
        if max_features is not None and len(selected_features) >= max_features:
            break

    return (
        selected_features,      # List of features in the order they were selected (this will be ALL features if max_features == None
        best_scores,            # List of cross-validation scores corresponding to each addition in the previous list
        best_feature_set,       # The subset of features that achieved the best CV score.
        best_score              # The best CV score
    )

# %%
# Your code here:  Run Forward Feature Selection, plot the results, and print out the Best Feature Set and the Best CV Score found. 
model = LinearRegression()

selected_features, best_scores, best_feature_set, best_score = forward_feature_selection(X_train,y_train,model,scoring='neg_mean_squared_error',cv=5,tol=None,max_features=None,n_jobs=1,verbose=True)

rmse_scores = [np.sqrt(score) for score in best_scores]
best_rmse_score = np.sqrt(best_score)

plt.figure(figsize=(12,6))
plt.plot(range(1, len(rmse_scores) + 1), rmse_scores, marker='o')
plt.xlabel("Number of Features Added")
plt.ylabel("CV RMSE ($)")
plt.title("Forward Feature Selection: CV RMSE vs. Features Added")
plt.xticks(
    range(1, len(selected_features) + 1), 
    selected_features, 
    rotation=60, 
    ha='right', 
    fontsize=8
)
plt.grid(True)
plt.tight_layout()
plt.show()

# 4. Print best feature subset and lowest RMSE
print("Best Feature Subset:", best_feature_set)
print("Best CV RMSE Score: ${:,.2f}".format(best_rmse_score))
# Out:
# Features: ['Overall Qual'], CV Score (MSE): 2190446626.8455
#
# Features: ['Overall Qual', 'Gr Liv Area'], CV Score (MSE): 1634711678.9460
#
# Features: ['Overall Qual', 'Gr Liv Area', 'BsmtFin SF 1'], CV Score (MSE): 1431514773.2791
#
# Features: ['Gr Liv Area', 'BsmtFin SF 1', 'Exter Qual'], CV Score (MSE): 1303120842.4610
#
# Features: ['BsmtFin SF 1', 'Exter Qual', 'Garage Cars'], CV Score (MSE): 1215929938.6529
#
# Features: ['Exter Qual', 'Garage Cars', 'MS SubClass'], CV Score (MSE): 1151052377.3098
#
# Features: ['Garage Cars', 'MS SubClass', 'Bsmt Exposure'], CV Score (MSE): 1108574238.0102
#
# Features: ['MS SubClass', 'Bsmt Exposure', 'Kitchen Qual'], CV Score (MSE): 1078501553.0717
#
# Features: ['Bsmt Exposure', 'Kitchen Qual', 'Year Built'], CV Score (MSE): 1054219329.0671
#
# Features: ['Kitchen Qual', 'Year Built', 'Overall Cond'], CV Score (MSE): 1033644755.3542
#
# Features: ['Year Built', 'Overall Cond', 'Screen Porch'], CV Score (MSE): 1017025814.7002
#
# Features: ['Overall Cond', 'Screen Porch', 'Lot Area'], CV Score (MSE): 1002076717.7966
#
# Features: ['Screen Porch', 'Lot Area', 'Bsmt Qual'], CV Score (MSE): 987026659.1167
#
# Features: ['Lot Area', 'Bsmt Qual', 'Mas Vnr Area'], CV Score (MSE): 976758087.7708
#
# Features: ['Bsmt Qual', 'Mas Vnr Area', 'Bsmt Full Bath'], CV Score (MSE): 968964332.1822
#
# Features: ['Mas Vnr Area', 'Bsmt Full Bath', 'Sale Condition'], CV Score (MSE): 961720188.5583
#
# Features: ['Bsmt Full Bath', 'Sale Condition', 'Fireplaces'], CV Score (MSE): 955847331.9063
#
# Features: ['Sale Condition', 'Fireplaces', 'Functional'], CV Score (MSE): 949260823.2658
#
# Features: ['Fireplaces', 'Functional', 'Yr Sold'], CV Score (MSE): 944858744.7424
#
# Features: ['Functional', 'Yr Sold', 'Neighborhood'], CV Score (MSE): 940966102.0861
#
# Features: ['Yr Sold', 'Neighborhood', 'Wood Deck SF'], CV Score (MSE): 937689092.7501
#
# Features: ['Neighborhood', 'Wood Deck SF', 'House Style'], CV Score (MSE): 934532366.2484
#
# Features: ['Wood Deck SF', 'House Style', 'Kitchen AbvGr'], CV Score (MSE): 931850299.5812
#
# Features: ['House Style', 'Kitchen AbvGr', 'Street'], CV Score (MSE): 929115070.9878
#
# Features: ['Kitchen AbvGr', 'Street', 'Roof Style'], CV Score (MSE): 927556522.5182
#
# Features: ['Street', 'Roof Style', 'Heating QC'], CV Score (MSE): 926370449.1919
#
# Features: ['Roof Style', 'Heating QC', 'Exterior 1st'], CV Score (MSE): 924347760.5579
#
# Features: ['Heating QC', 'Exterior 1st', 'Garage Cond'], CV Score (MSE): 923681684.8343
#
# Features: ['Exterior 1st', 'Garage Cond', 'Bldg Type'], CV Score (MSE): 923019189.2154
#
# Features: ['Garage Cond', 'Bldg Type', 'Land Slope'], CV Score (MSE): 922306229.7295
#
# Features: ['Bldg Type', 'Land Slope', 'Land Contour'], CV Score (MSE): 921465231.3533
#
# Features: ['Land Slope', 'Land Contour', 'Enclosed Porch'], CV Score (MSE): 921067026.1650
#
# Features: ['Land Contour', 'Enclosed Porch', 'Low Qual Fin SF'], CV Score (MSE): 920679988.5525
#
# Features: ['Enclosed Porch', 'Low Qual Fin SF', 'BsmtFin Type 1'], CV Score (MSE): 920340487.6362
#
# Features: ['Low Qual Fin SF', 'BsmtFin Type 1', 'Exterior 2nd'], CV Score (MSE): 920018792.8690
#
# Features: ['BsmtFin Type 1', 'Exterior 2nd', 'Garage Yr Blt'], CV Score (MSE): 919701830.9779
#
# Features: ['Exterior 2nd', 'Garage Yr Blt', 'Garage Qual'], CV Score (MSE): 919219516.8317
#
# Features: ['Garage Yr Blt', 'Garage Qual', 'Lot Shape'], CV Score (MSE): 919028114.3143
#
# Features: ['Garage Qual', 'Lot Shape', 'Half Bath'], CV Score (MSE): 918971046.6477
#
# Features: ['Lot Shape', 'Half Bath', 'MS Zoning'], CV Score (MSE): 918904292.2245
#
# Features: ['Half Bath', 'MS Zoning', 'Exter Cond'], CV Score (MSE): 918859879.5191
#
# Features: ['MS Zoning', 'Exter Cond', 'Bsmt Cond'], CV Score (MSE): 918973958.8883
#
# Features: ['Exter Cond', 'Bsmt Cond', 'Sale Type'], CV Score (MSE): 919148814.9774
#
# Features: ['Bsmt Cond', 'Sale Type', 'Garage Type'], CV Score (MSE): 919435290.3986
#
# Features: ['Sale Type', 'Garage Type', 'Electrical'], CV Score (MSE): 919759251.6966
#
# Features: ['Garage Type', 'Electrical', 'Paved Drive'], CV Score (MSE): 920108488.5341
#
# Features: ['Electrical', 'Paved Drive', 'BsmtFin SF 2'], CV Score (MSE): 920593468.9960
#
# Features: ['Paved Drive', 'BsmtFin SF 2', 'Central Air'], CV Score (MSE): 921109400.4608
#
# Features: ['BsmtFin SF 2', 'Central Air', 'Year Remod/Add'], CV Score (MSE): 921657549.2631
#
# Features: ['Central Air', 'Year Remod/Add', 'Lot Config'], CV Score (MSE): 922307078.1305
#
# Features: ['Year Remod/Add', 'Lot Config', 'Condition 1'], CV Score (MSE): 922929601.9095
#
# Features: ['Lot Config', 'Condition 1', '3Ssn Porch'], CV Score (MSE): 923832124.6023
#
# Features: ['Condition 1', '3Ssn Porch', 'Foundation'], CV Score (MSE): 924740609.1547
#
# Features: ['3Ssn Porch', 'Foundation', 'Condition 2'], CV Score (MSE): 925679151.9552
#
# Features: ['Foundation', 'Condition 2', 'Mo Sold'], CV Score (MSE): 926623578.2680
#
# Features: ['Condition 2', 'Mo Sold', 'TotRms AbvGrd'], CV Score (MSE): 927765692.5409
#
# Features: ['Mo Sold', 'TotRms AbvGrd', 'BsmtFin Type 2'], CV Score (MSE): 928935113.3419
#
# Features: ['TotRms AbvGrd', 'BsmtFin Type 2', 'Heating'], CV Score (MSE): 930297603.8614
#
# Features: ['BsmtFin Type 2', 'Heating', 'Garage Finish'], CV Score (MSE): 931767520.4010
#
# Features: ['Heating', 'Garage Finish', 'Open Porch SF'], CV Score (MSE): 933684387.9082
#
# Features: ['Garage Finish', 'Open Porch SF', '2nd Flr SF'], CV Score (MSE): 935709116.9011
#
# Features: ['Open Porch SF', '2nd Flr SF', '1st Flr SF'], CV Score (MSE): 935709116.9012
#
# Features: ['2nd Flr SF', '1st Flr SF', 'Full Bath'], CV Score (MSE): 937393509.4965
#
# Features: ['1st Flr SF', 'Full Bath', 'Utilities'], CV Score (MSE): 939451010.8664
#
# Features: ['Full Bath', 'Utilities', 'Bsmt Half Bath'], CV Score (MSE): 941581284.8711
#
# Features: ['Utilities', 'Bsmt Half Bath', 'Roof Matl'], CV Score (MSE): 943524745.2394
#
# Features: ['Bsmt Half Bath', 'Roof Matl', 'Bedroom AbvGr'], CV Score (MSE): 946586274.1642
#
# Features: ['Roof Matl', 'Bedroom AbvGr', 'Lot Frontage'], CV Score (MSE): 950233767.7147
#
# Features: ['Bedroom AbvGr', 'Lot Frontage', 'Garage Area'], CV Score (MSE): 953058493.3123
#
# Features: ['Lot Frontage', 'Garage Area', 'Pool Area'], CV Score (MSE): 956596710.7330
#
# Features: ['Garage Area', 'Pool Area', 'Total Bsmt SF'], CV Score (MSE): 970844660.6669
#
# Features: ['Pool Area', 'Total Bsmt SF', 'Bsmt Unf SF'], CV Score (MSE): 970870767.3240
#
# Features: ['Total Bsmt SF', 'Bsmt Unf SF', 'Misc Val'], CV Score (MSE): 991331210.4187
# Best Feature Subset: ['Overall Qual', 'Gr Liv Area', 'BsmtFin SF 1', 'Exter Qual', 'Garage Cars', 'MS SubClass', 'Bsmt Exposure', 'Kitchen Qual', 'Year Built', 'Overall Cond', 'Screen Porch', 'Lot Area', 'Bsmt Qual', 'Mas Vnr Area', 'Bsmt Full Bath', 'Sale Condition', 'Fireplaces', 'Functional', 'Yr Sold', 'Neighborhood', 'Wood Deck SF', 'House Style', 'Kitchen AbvGr', 'Street', 'Roof Style', 'Heating QC', 'Exterior 1st', 'Garage Cond', 'Bldg Type', 'Land Slope', 'Land Contour', 'Enclosed Porch', 'Low Qual Fin SF', 'BsmtFin Type 1', 'Exterior 2nd', 'Garage Yr Blt', 'Garage Qual', 'Lot Shape', 'Half Bath', 'MS Zoning', 'Exter Cond']
# Best CV RMSE Score: $30,312.70

# %% [markdown]
# ### Problem One Graded Questions
#
# Assign `a1a` to the number of features in the best feature set found

# %%
# Your answer here; use an expression, not a constant derived by examining the data

a1a = len(best_feature_set)                     # replace 0 with an expression

# %%
# Do not change this cell in any way

print(f"a1a = {a1a}")
# Out:
# a1a = 41

# %% [markdown]
# Assign `a1b` to the best CV RMSE score found.

# %%
# Your answer here; use an expression, not a constant derived by examining the data

a1b =np.sqrt(best_score)                 # replace 0 with an expression

# %%
# Do not change this cell in any way

print(f"a1b = ${a1b:,.2f}")
# Out:
# a1b = $30,312.70

# %% [markdown]
# ## **Problem Two: Backward Selection with the Ames Dataset**
#
# Now, repeat the same process as in Problem One, but using the `backward_feature_selection` algorithm from this week’s video notebook. Again, we will use 5-Fold CV scoring.
#
# **Steps to Follow:**
# 1. **Observe** that we have provided the `backward_feature_selection` algorithm from this week's video notebook for you to use.
# 2. **Run** the backward selection algorithm on the Ames dataset (`X_train` and `y_train`).
# 3. **Plot** the results: Display the Root Mean Squared Error (RMSE) vs. the features removed by the algorithm.
# 4. **Print** the Best Feature Set found by backward selection and the corresponding best CV RMSE Score.

# %%
# Backward Feature Selection

def backward_feature_selection(X, y, model, 
                               scoring='neg_mean_squared_error', 
                               cv = 5, 
                               tol=None,               # None = no delta cutoff
                                                       # use 0.0 for "no further improvements"
                                                       # and 1e-4 for "point of diminishing returns"                                      
                               max_features=None,      # If None, remove features until only 1 remains
                                                       # Otherwise, stop when this many features remain
                               n_jobs=-1,
                               verbose=True
                              ):
    
    # Helper function to compute CV score using LinearRegression
    def cv_score(features):
        return -cross_val_score(model, X[features], y, 
                                scoring=scoring, cv=cv, 
                                n_jobs=n_jobs          ).mean()
    
    # Start with all features (using a list for easier manipulation)
    features_remaining = list(X.columns)
    
    # Compute initial CV score with the full feature set
    initial_score = cv_score(features_remaining)
    
    # Initialize tracking variables
    best_score        = initial_score                # Best (lowest) CV score observed so far
    best_feature_set  = features_remaining.copy()    # Feature set corresponding to best_score
    selected_features = ['NONE']                     # List to record the order in which features are removed
    best_scores       = [initial_score]              # List to record the CV score after each removal (starting with full set)
    
    if verbose:
        print("Start with full set of features:")
        print(f'{features_remaining}  CV score (MSE): {np.around(initial_score, 4)}\n')
    
    # Determine the target number of features to keep:
    # For backward elimination, if max_features is None, we remove until 1 feature remains.
    target_feature_count = 1 if max_features is None else max_features
    
    prev_score = initial_score
    round_num = 1
    # Continue removing features until we reach the target count
    while len(features_remaining) > target_feature_count:
        if verbose:
            print(f'Round {round_num}:')
            
        # Initialize variables to track the best removal in this round
        lowest_score = float('inf')
        feature_to_remove = None
        best_new_features = None
        
        # Try removing each feature one at a time
        for feature in features_remaining:
            new_feature_set = features_remaining.copy()
            new_feature_set.remove(feature)
            new_score = cv_score(new_feature_set)
            if verbose:
                print('Trying removal of:',feature, np.around(new_score, 4))
            if new_score < lowest_score:
                lowest_score = new_score
                feature_to_remove = feature
                best_new_features = new_feature_set
        
        # Check if improvement is significant enough (if tol is set)
        if tol is not None and (prev_score - lowest_score) < tol:
            if verbose:
                print("\nStopping early due to minimal improvement.")
            break
        
        # Update the best score and feature set if current removal improves performance
        if lowest_score < best_score:
            best_score = lowest_score
            best_feature_set = best_new_features.copy()
        
        # Update trackers for this round
        prev_score = lowest_score
        features_remaining = best_new_features
        selected_features.append(feature_to_remove)
        best_scores.append(lowest_score)
        
        if verbose:
            print(f'\nRemoving {feature_to_remove}:  CV score (MSE) {np.around(lowest_score, 4)}\n')
        round_num += 1

    return (
        selected_features,      # Order in which features were removed
        best_scores,            # CV scores after each removal step
        best_feature_set,       # Feature set that achieved the best CV score
        best_score              # Best (lowest) CV score
    )

# %%
# Your code here:  Run Backward Feature Selection, plot the results, and print out the Best Feature Set and the Best CV RMSE Score found. 
model = LinearRegression()

# 2. Run backward feature selection
removed_features, mse_scores_backward, best_feature_set_backward, best_mse_score_backward = backward_feature_selection(
    X_train, 
    y_train, 
    model, 
    scoring='neg_mean_squared_error', 
    cv=5, 
    tol=None, 
    max_features=None,  # Will stop when only 1 feature is left
    n_jobs=-1, 
    verbose=True
)

# 3. Convert MSE to RMSE for interpretability
rmse_scores_backward = [np.sqrt(score) for score in mse_scores_backward]
best_rmse_score_backward = np.sqrt(best_mse_score_backward)

# 4. Plot RMSE vs. Feature Removals
plt.figure(figsize=(12, 6))
plt.plot(range(len(rmse_scores_backward)), rmse_scores_backward, marker='o')
plt.xlabel("Number of Features Removed")
plt.ylabel("CV RMSE ($)")
plt.title("Backward Feature Selection: CV RMSE vs. Features Removed")
plt.xticks(
    range(len(removed_features)), 
    removed_features, 
    rotation=60, 
    ha='right', 
    fontsize=8
)
plt.grid(True)
plt.tight_layout()
plt.show()

# 5. Print results
print("Best Feature Subset (Backward Selection):", best_feature_set_backward)
print("Best CV RMSE Score (Backward Selection): ${:,.2f}".format(best_rmse_score_backward))
# Out:
# Start with full set of features:
# ['MS SubClass', 'MS Zoning', 'Lot Frontage', 'Lot Area', 'Street', 'Lot Shape', 'Land Contour', 'Utilities', 'Lot Config', 'Land Slope', 'Neighborhood', 'Condition 1', 'Condition 2', 'Bldg Type', 'House Style', 'Overall Qual', 'Overall Cond', 'Year Built', 'Year Remod/Add', 'Roof Style', 'Roof Matl', 'Exterior 1st', 'Exterior 2nd', 'Mas Vnr Area', 'Exter Qual', 'Exter Cond', 'Foundation', 'Bsmt Qual', 'Bsmt Cond', 'Bsmt Exposure', 'BsmtFin Type 1', 'BsmtFin SF 1', 'BsmtFin Type 2', 'BsmtFin SF 2', 'Bsmt Unf SF', 'Total Bsmt SF', 'Heating', 'Heating QC', 'Central Air', 'Electrical', '1st Flr SF', '2nd Flr SF', 'Low Qual Fin SF', 'Gr Liv Area', 'Bsmt Full Bath', 'Bsmt Half Bath', 'Full Bath', 'Half Bath', 'Bedroom AbvGr', 'Kitchen AbvGr', 'Kitchen Qual', 'TotRms AbvGrd', 'Functional', 'Fireplaces', 'Garage Type', 'Garage Yr Blt', 'Garage Finish', 'Garage Cars', 'Garage Area', 'Garage Qual', 'Garage Cond', 'Paved Drive', 'Wood Deck SF', 'Open Porch SF', 'Enclosed Porch', '3Ssn Porch', 'Screen Porch', 'Pool Area', 'Misc Val', 'Mo Sold', 'Yr Sold', 'Sale Type', 'Sale Condition']  CV score (MSE): 991331210.4185
#
# Round 1:
# Trying removal of: MS SubClass 995806381.6755
# Trying removal of: MS Zoning 991537436.6473
# Trying removal of: Lot Frontage 987246519.3181
# Trying removal of: Lot Area 998533688.9047
# Trying removal of: Street 992505846.7598
# Trying removal of: Lot Shape 992283757.9678
# Trying removal of: Land Contour 992442476.416
# Trying removal of: Utilities 989215966.1656
# Trying removal of: Lot Config 990495122.9418
# Trying removal of: Land Slope 992516625.7626
# Trying removal of: Neighborhood 995131417.8398
# Trying removal of: Condition 1 990530131.6108
# Trying removal of: Condition 2 991356263.9764
# Trying removal of: Bldg Type 993329344.0735
# Trying removal of: House Style 994301386.9199
# Trying removal of: Overall Qual 1092955309.1627
# Trying removal of: Overall Cond 1003615400.3956
# Trying removal of: Year Built 997510321.9551
# Trying removal of: Year Remod/Add 990720128.5066
# Trying removal of: Roof Style 995548690.8867
# Trying removal of: Roof Matl 988074830.4703
# Trying removal of: Exterior 1st 995594880.1501
# Trying removal of: Exterior 2nd 991461731.4156
# Trying removal of: Mas Vnr Area 998035339.4084
# Trying removal of: Exter Qual 1016804043.7241
# Trying removal of: Exter Cond 989972407.7518
# Trying removal of: Foundation 990968660.0848
# Trying removal of: Bsmt Qual 1005411066.4066
# Trying removal of: Bsmt Cond 991629979.9978
# Trying removal of: Bsmt Exposure 1009815291.8361
# Trying removal of: BsmtFin Type 1 994671963.8451
# Trying removal of: BsmtFin SF 1 991197271.5048
# Trying removal of: BsmtFin Type 2 989891559.5684
# Trying removal of: BsmtFin SF 2 991233282.9341
# Trying removal of: Bsmt Unf SF 991254890.2703
# Trying removal of: Total Bsmt SF 991296761.2571
# Trying removal of: Heating 990714228.9774
# Trying removal of: Heating QC 991919360.2024
# Trying removal of: Central Air 990823041.5062
# Trying removal of: Electrical 991055788.2048
# Trying removal of: 1st Flr SF 991331210.4186
# Trying removal of: 2nd Flr SF 991331210.4187
# Trying removal of: Low Qual Fin SF 991331210.4187
# Trying removal of: Gr Liv Area 991331210.4187
# Trying removal of: Bsmt Full Bath 995082703.7188
# Trying removal of: Bsmt Half Bath 989410144.9167
# Trying removal of: Full Bath 990689897.9905
# Trying removal of: Half Bath 991082787.2465
# Trying removal of: Bedroom AbvGr 988045921.0025
# Trying removal of: Kitchen AbvGr 990677069.8194
# Trying removal of: Kitchen Qual 1006127075.9962
# Trying removal of: TotRms AbvGrd 990592984.264
# Trying removal of: Functional 998614425.9143
# Trying removal of: Fireplaces 996907045.232
# Trying removal of: Garage Type 989019282.5131
# Trying removal of: Garage Yr Blt 991558051.9995
# Trying removal of: Garage Finish 990077775.6266
# Trying removal of: Garage Cars 990101507.811
# Trying removal of: Garage Area 988066741.9518
# Trying removal of: Garage Qual 991595988.2995
# Trying removal of: Garage Cond 992208629.8178
# Trying removal of: Paved Drive 990340101.1741
# Trying removal of: Wood Deck SF 993726707.6039
# Trying removal of: Open Porch SF 990662748.9188
# Trying removal of: Enclosed Porch 992386993.9022
# Trying removal of: 3Ssn Porch 990288112.2388
# Trying removal of: Screen Porch 1009833439.0686
# Trying removal of: Pool Area 987759797.9338
# Trying removal of: Misc Val 970870767.3239
# Trying removal of: Mo Sold 990580461.4595
# Trying removal of: Yr Sold 994739207.5778
# Trying removal of: Sale Type 990789273.0905
# Trying removal of: Sale Condition 999735935.1718
#
# Removing Misc Val:  CV score (MSE) 970870767.3239
#
# Round 2:
# Trying removal of: MS SubClass 975000772.0706
# Trying removal of: MS Zoning 971034009.2478
# Trying removal of: Lot Frontage 967522563.9609
# Trying removal of: Lot Area 976289913.3518
# Trying removal of: Street 971407805.1349
# Trying removal of: Lot Shape 970967534.6412
# Trying removal of: Land Contour 971975708.4941
# Trying removal of: Utilities 968390560.5345
# Trying removal of: Lot Config 970115071.8537
# Trying removal of: Land Slope 971561304.9541
# Trying removal of: Neighborhood 974218465.5107
# Trying removal of: Condition 1 969892908.8171
# Trying removal of: Condition 2 969988517.5025
# Trying removal of: Bldg Type 973112110.6991
# Trying removal of: House Style 972931633.9164
# Trying removal of: Overall Qual 1069597104.9826
# Trying removal of: Overall Cond 982354505.5557
# Trying removal of: Year Built 976675415.8457
# Trying removal of: Year Remod/Add 970472543.467
# Trying removal of: Roof Style 971622662.2232
# Trying removal of: Roof Matl 968369708.8672
# Trying removal of: Exterior 1st 974745390.2151
# Trying removal of: Exterior 2nd 970787761.5444
# Trying removal of: Mas Vnr Area 979907158.7893
# Trying removal of: Exter Qual 998109386.9731
# Trying removal of: Exter Cond 970294263.8028
# Trying removal of: Foundation 970645992.3377
# Trying removal of: Bsmt Qual 983542499.5115
# Trying removal of: Bsmt Cond 971041280.6667
# Trying removal of: Bsmt Exposure 987889246.0904
# Trying removal of: BsmtFin Type 1 972560879.9051
# Trying removal of: BsmtFin SF 1 970801676.5289
# Trying removal of: BsmtFin Type 2 969613894.9342
# Trying removal of: BsmtFin SF 2 970822628.2927
# Trying removal of: Bsmt Unf SF 970844660.6667
# Trying removal of: Total Bsmt SF 970874440.5443
# Trying removal of: Heating 969760289.8718
# Trying removal of: Heating QC 971715709.1256
# Trying removal of: Central Air 970453318.7953
# Trying removal of: Electrical 970651600.9916
# Trying removal of: 1st Flr SF 970870767.3239
# Trying removal of: 2nd Flr SF 970870767.3239
# Trying removal of: Low Qual Fin SF 970870767.3238
# Trying removal of: Gr Liv Area 970870767.3239
# Trying removal of: Bsmt Full Bath 977322625.9553
# Trying removal of: Bsmt Half Bath 968486276.7057
# Trying removal of: Full Bath 970176153.6807
# Trying removal of: Half Bath 970792858.6893
# Trying removal of: Bedroom AbvGr 966973992.6138
# Trying removal of: Kitchen AbvGr 971430471.2797
# Trying removal of: Kitchen Qual 984416899.7232
# Trying removal of: TotRms AbvGrd 969008094.9381
# Trying removal of: Functional 979949387.2957
# Trying removal of: Fireplaces 976706161.6524
# Trying removal of: Garage Type 969404339.5829
# Trying removal of: Garage Yr Blt 971288498.1359
# Trying removal of: Garage Finish 969545501.1936
# Trying removal of: Garage Cars 970502619.9244
# Trying removal of: Garage Area 967950038.2524
# Trying removal of: Garage Qual 971268282.324
# Trying removal of: Garage Cond 971775866.8449
# Trying removal of: Paved Drive 970083562.6426
# Trying removal of: Wood Deck SF 972593536.8213
# Trying removal of: Open Porch SF 969236805.1936
# Trying removal of: Enclosed Porch 971843107.7916
# Trying removal of: 3Ssn Porch 969990479.7332
# Trying removal of: Screen Porch 987822911.7085
# Trying removal of: Pool Area 966714738.7906
# Trying removal of: Mo Sold 969896768.1736
# Trying removal of: Yr Sold 974378972.1659
# Trying removal of: Sale Type 970353419.9236
# Trying removal of: Sale Condition 979106257.6537
#
# Removing Pool Area:  CV score (MSE) 966714738.7906
#
# Round 3:
# Trying removal of: MS SubClass 970878156.118
# Trying removal of: MS Zoning 966814908.042
# Trying removal of: Lot Frontage 962256640.8003
# Trying removal of: Lot Area 971913919.4041
# Trying removal of: Street 967115253.1083
# Trying removal of: Lot Shape 966878536.019
# Trying removal of: Land Contour 967831919.7719
# Trying removal of: Utilities 964181626.3772
# Trying removal of: Lot Config 965941397.6881
# Trying removal of: Land Slope 967569384.3376
# Trying removal of: Neighborhood 970077960.9961
# Trying removal of: Condition 1 965730812.4375
# Trying removal of: Condition 2 965827704.3956
# Trying removal of: Bldg Type 968830031.2637
# Trying removal of: House Style 968589222.0408
# Trying removal of: Overall Qual 1065420865.9334
# Trying removal of: Overall Cond 977896948.4546
# Trying removal of: Year Built 972414512.0306
# Trying removal of: Year Remod/Add 966400628.1436
# Trying removal of: Roof Style 967684862.4526
# Trying removal of: Roof Matl 963775023.3461
# Trying removal of: Exterior 1st 970424567.937
# Trying removal of: Exterior 2nd 966595898.0612
# Trying removal of: Mas Vnr Area 975586035.8497
# Trying removal of: Exter Qual 992980343.3822
# Trying removal of: Exter Cond 966376412.4683
# Trying removal of: Foundation 966542841.075
# Trying removal of: Bsmt Qual 979268450.0373
# Trying removal of: Bsmt Cond 966764604.1113
# Trying removal of: Bsmt Exposure 983469123.549
# Trying removal of: BsmtFin Type 1 968493156.2838
# Trying removal of: BsmtFin SF 1 966644340.1674
# Trying removal of: BsmtFin Type 2 965346523.0297
# Trying removal of: BsmtFin SF 2 966666202.6252
# Trying removal of: Bsmt Unf SF 966685049.446
# Trying removal of: Total Bsmt SF 966712587.5195
# Trying removal of: Heating 965579203.423
# Trying removal of: Heating QC 967725880.6818
# Trying removal of: Central Air 966287618.7592
# Trying removal of: Electrical 966515637.8737
# Trying removal of: 1st Flr SF 966714738.7903
# Trying removal of: 2nd Flr SF 966714738.7904
# Trying removal of: Low Qual Fin SF 966714738.7905
# Trying removal of: Gr Liv Area 966714738.7903
# Trying removal of: Bsmt Full Bath 973044868.9698
# Trying removal of: Bsmt Half Bath 964751723.6638
# Trying removal of: Full Bath 966177629.1493
# Trying removal of: Half Bath 966541051.7689
# Trying removal of: Bedroom AbvGr 963190829.0001
# Trying removal of: Kitchen AbvGr 967207193.4987
# Trying removal of: Kitchen Qual 980154421.7099
# Trying removal of: TotRms AbvGrd 964599832.3648
# Trying removal of: Functional 975670060.795
# Trying removal of: Fireplaces 972264894.8876
# Trying removal of: Garage Type 965456344.8957
# Trying removal of: Garage Yr Blt 967122000.7346
# Trying removal of: Garage Finish 965437283.0334
# Trying removal of: Garage Cars 966177375.7187
# Trying removal of: Garage Area 963968262.0006
# Trying removal of: Garage Qual 967056875.1017
# Trying removal of: Garage Cond 967877885.4466
# Trying removal of: Paved Drive 965970313.4916
# Trying removal of: Wood Deck SF 968276420.4214
# Trying removal of: Open Porch SF 965390467.8853
# Trying removal of: Enclosed Porch 967705489.8946
# Trying removal of: 3Ssn Porch 965808373.9467
# Trying removal of: Screen Porch 983248257.871
# Trying removal of: Mo Sold 965549306.8219
# Trying removal of: Yr Sold 970244203.9525
# Trying removal of: Sale Type 966347582.0097
# Trying removal of: Sale Condition 975033785.9111
#
# Removing Lot Frontage:  CV score (MSE) 962256640.8003
#
# Round 4:
# Trying removal of: MS SubClass 965894659.8456
# Trying removal of: MS Zoning 962187176.7698
# Trying removal of: Lot Area 965193200.495
# Trying removal of: Street 963055014.3124
# Trying removal of: Lot Shape 962595113.2724
# Trying removal of: Land Contour 963327275.2807
# Trying removal of: Utilities 959594060.388
# Trying removal of: Lot Config 961665725.8514
# Trying removal of: Land Slope 963009772.5325
# Trying removal of: Neighborhood 965662669.0498
# Trying removal of: Condition 1 961311196.844
# Trying removal of: Condition 2 961490126.8692
# Trying removal of: Bldg Type 963874331.0704
# Trying removal of: House Style 963866112.9517
# Trying removal of: Overall Qual 1061748235.577
# Trying removal of: Overall Cond 974038179.2651
# Trying removal of: Year Built 967424325.3013
# Trying removal of: Year Remod/Add 961925568.7741
# Trying removal of: Roof Style 963346330.9386
# Trying removal of: Roof Matl 959162114.3961
# Trying removal of: Exterior 1st 965569824.2899
# Trying removal of: Exterior 2nd 961597509.2357
# Trying removal of: Mas Vnr Area 971100337.1795
# Trying removal of: Exter Qual 986748488.2997
# Trying removal of: Exter Cond 961743043.803
# Trying removal of: Foundation 962101731.4748
# Trying removal of: Bsmt Qual 974911154.4961
# Trying removal of: Bsmt Cond 962328990.8685
# Trying removal of: Bsmt Exposure 978117703.1767
# Trying removal of: BsmtFin Type 1 963947524.7459
# Trying removal of: BsmtFin SF 1 962228577.4745
# Trying removal of: BsmtFin Type 2 960913958.431
# Trying removal of: BsmtFin SF 2 962237129.0454
# Trying removal of: Bsmt Unf SF 962246636.57
# Trying removal of: Total Bsmt SF 962251227.97
# Trying removal of: Heating 961052356.9854
# Trying removal of: Heating QC 963213055.023
# Trying removal of: Central Air 961868152.6214
# Trying removal of: Electrical 962120419.0906
# Trying removal of: 1st Flr SF 962256640.8004
# Trying removal of: 2nd Flr SF 962256640.8002
# Trying removal of: Low Qual Fin SF 962256640.8004
# Trying removal of: Gr Liv Area 962256640.8003
# Trying removal of: Bsmt Full Bath 968240159.8666
# Trying removal of: Bsmt Half Bath 960157803.4146
# Trying removal of: Full Bath 961807033.3915
# Trying removal of: Half Bath 961962289.8088
# Trying removal of: Bedroom AbvGr 959023682.5726
# Trying removal of: Kitchen AbvGr 963315047.2634
# Trying removal of: Kitchen Qual 975443919.4072
# Trying removal of: TotRms AbvGrd 960005447.9533
# Trying removal of: Functional 970818286.3557
# Trying removal of: Fireplaces 967384171.2259
# Trying removal of: Garage Type 962272540.178
# Trying removal of: Garage Yr Blt 962957657.5175
# Trying removal of: Garage Finish 960938130.8688
# Trying removal of: Garage Cars 961369329.6256
# Trying removal of: Garage Area 958510431.1129
# Trying removal of: Garage Qual 962764558.1154
# Trying removal of: Garage Cond 963210787.983
# Trying removal of: Paved Drive 961554254.8606
# Trying removal of: Wood Deck SF 964122227.9507
# Trying removal of: Open Porch SF 961038275.1071
# Trying removal of: Enclosed Porch 963075126.339
# Trying removal of: 3Ssn Porch 961374790.6758
# Trying removal of: Screen Porch 977954468.956
# Trying removal of: Mo Sold 961060446.4232
# Trying removal of: Yr Sold 965913641.197
# Trying removal of: Sale Type 961961289.6485
# Trying removal of: Sale Condition 970648535.7864
#
# Removing Garage Area:  CV score (MSE) 958510431.1129
#
# Round 5:
# Trying removal of: MS SubClass 962328898.9135
# Trying removal of: MS Zoning 958323923.7744
# Trying removal of: Lot Area 961351457.4215
# Trying removal of: Street 959352148.8218
# Trying removal of: Lot Shape 958800528.946
# Trying removal of: Land Contour 959654123.5924
# Trying removal of: Utilities 955861415.6652
# Trying removal of: Lot Config 957965259.1263
# Trying removal of: Land Slope 959155371.5528
# Trying removal of: Neighborhood 961964187.9365
# Trying removal of: Condition 1 957556274.0132
# Trying removal of: Condition 2 957671313.1208
# Trying removal of: Bldg Type 960110161.0459
# Trying removal of: House Style 960193383.3831
# Trying removal of: Overall Qual 1057780839.7225
# Trying removal of: Overall Cond 970291445.4171
# Trying removal of: Year Built 963845009.7639
# Trying removal of: Year Remod/Add 958244928.9415
# Trying removal of: Roof Style 959700989.9258
# Trying removal of: Roof Matl 955470859.3574
# Trying removal of: Exterior 1st 961953554.3353
# Trying removal of: Exterior 2nd 958109529.9797
# Trying removal of: Mas Vnr Area 967577775.6866
# Trying removal of: Exter Qual 982786507.3602
# Trying removal of: Exter Cond 958197676.5355
# Trying removal of: Foundation 958390886.5574
# Trying removal of: Bsmt Qual 971277105.9272
# Trying removal of: Bsmt Cond 958666085.6974
# Trying removal of: Bsmt Exposure 974176132.742
# Trying removal of: BsmtFin Type 1 960181007.9223
# Trying removal of: BsmtFin SF 1 958483037.9639
# Trying removal of: BsmtFin Type 2 957133910.4935
# Trying removal of: BsmtFin SF 2 958491762.162
# Trying removal of: Bsmt Unf SF 958500752.0308
# Trying removal of: Total Bsmt SF 958504938.5685
# Trying removal of: Heating 957307518.8114
# Trying removal of: Heating QC 959373328.0792
# Trying removal of: Central Air 958107033.6289
# Trying removal of: Electrical 958379938.0016
# Trying removal of: 1st Flr SF 958510431.1128
# Trying removal of: 2nd Flr SF 958510431.1127
# Trying removal of: Low Qual Fin SF 958510431.1127
# Trying removal of: Gr Liv Area 958510431.1129
# Trying removal of: Bsmt Full Bath 964182387.4736
# Trying removal of: Bsmt Half Bath 956449109.7058
# Trying removal of: Full Bath 957725462.2475
# Trying removal of: Half Bath 958095021.6635
# Trying removal of: Bedroom AbvGr 955181255.789
# Trying removal of: Kitchen AbvGr 959640334.9476
# Trying removal of: Kitchen Qual 971442190.9619
# Trying removal of: TotRms AbvGrd 956276946.4899
# Trying removal of: Functional 967233090.7954
# Trying removal of: Fireplaces 963666385.0854
# Trying removal of: Garage Type 958222520.4396
# Trying removal of: Garage Yr Blt 959039200.6068
# Trying removal of: Garage Finish 957186192.0424
# Trying removal of: Garage Cars 969491468.0227
# Trying removal of: Garage Qual 959050595.0309
# Trying removal of: Garage Cond 959538824.17
# Trying removal of: Paved Drive 957992663.9586
# Trying removal of: Wood Deck SF 960393053.1987
# Trying removal of: Open Porch SF 957167764.4894
# Trying removal of: Enclosed Porch 959408908.6851
# Trying removal of: 3Ssn Porch 957671859.6973
# Trying removal of: Screen Porch 974329367.7246
# Trying removal of: Mo Sold 957276875.8472
# Trying removal of: Yr Sold 961960405.1969
# Trying removal of: Sale Type 958217123.6243
# Trying removal of: Sale Condition 966763202.8783
#
# Removing Bedroom AbvGr:  CV score (MSE) 955181255.789
#
# Round 6:
# Trying removal of: MS SubClass 958738619.4138
# Trying removal of: MS Zoning 955033317.6611
# Trying removal of: Lot Area 957954418.0802
# Trying removal of: Street 956273048.4168
# Trying removal of: Lot Shape 955421149.1654
# Trying removal of: Land Contour 956341319.0785
# Trying removal of: Utilities 952470578.5981
# Trying removal of: Lot Config 954642294.2565
# Trying removal of: Land Slope 956070396.6124
# Trying removal of: Neighborhood 958492177.9748
# Trying removal of: Condition 1 954167207.6429
# Trying removal of: Condition 2 954286737.0976
# Trying removal of: Bldg Type 956693993.4514
# Trying removal of: House Style 957113257.2471
# Trying removal of: Overall Qual 1056354174.4361
# Trying removal of: Overall Cond 967282428.848
# Trying removal of: Year Built 960331772.2935
# Trying removal of: Year Remod/Add 954664994.9481
# Trying removal of: Roof Style 956545042.7283
# Trying removal of: Roof Matl 952416525.7479
# Trying removal of: Exterior 1st 958167776.8104
# Trying removal of: Exterior 2nd 954513534.1889
# Trying removal of: Mas Vnr Area 964022308.8186
# Trying removal of: Exter Qual 980213830.0561
# Trying removal of: Exter Cond 954915628.3256
# Trying removal of: Foundation 955127393.4095
# Trying removal of: Bsmt Qual 969633872.6477
# Trying removal of: Bsmt Cond 955471918.8121
# Trying removal of: Bsmt Exposure 970947643.7089
# Trying removal of: BsmtFin Type 1 956781695.6106
# Trying removal of: BsmtFin SF 1 955157030.4797
# Trying removal of: BsmtFin Type 2 953835109.7727
# Trying removal of: BsmtFin SF 2 955165988.7577
# Trying removal of: Bsmt Unf SF 955173070.1668
# Trying removal of: Total Bsmt SF 955175326.8907
# Trying removal of: Heating 954109905.9524
# Trying removal of: Heating QC 956399856.2793
# Trying removal of: Central Air 954709503.5483
# Trying removal of: Electrical 955020750.19
# Trying removal of: 1st Flr SF 955181255.7892
# Trying removal of: 2nd Flr SF 955181255.7893
# Trying removal of: Low Qual Fin SF 955181255.7891
# Trying removal of: Gr Liv Area 955181255.789
# Trying removal of: Bsmt Full Bath 960628663.2473
# Trying removal of: Bsmt Half Bath 953469644.5251
# Trying removal of: Full Bath 953535450.4213
# Trying removal of: Half Bath 954656853.1253
# Trying removal of: Kitchen AbvGr 956749721.2321
# Trying removal of: Kitchen Qual 968450414.2297
# Trying removal of: TotRms AbvGrd 953859167.3042
# Trying removal of: Functional 964047523.1201
# Trying removal of: Fireplaces 961795879.842
# Trying removal of: Garage Type 954842302.931
# Trying removal of: Garage Yr Blt 955830629.7778
# Trying removal of: Garage Finish 953680491.065
# Trying removal of: Garage Cars 967321492.399
# Trying removal of: Garage Qual 955855602.9453
# Trying removal of: Garage Cond 956276086.4834
# Trying removal of: Paved Drive 954580275.1288
# Trying removal of: Wood Deck SF 957106894.8872
# Trying removal of: Open Porch SF 953561999.2997
# Trying removal of: Enclosed Porch 956123750.3908
# Trying removal of: 3Ssn Porch 954163713.1104
# Trying removal of: Screen Porch 970359745.1406
# Trying removal of: Mo Sold 954049222.5326
# Trying removal of: Yr Sold 958784861.1121
# Trying removal of: Sale Type 955201433.8528
# Trying removal of: Sale Condition 963956427.3537
#
# Removing Roof Matl:  CV score (MSE) 952416525.7479
#
# Round 7:
# Trying removal of: MS SubClass 956292030.2611
# Trying removal of: MS Zoning 952324220.3341
# Trying removal of: Lot Area 955953255.5962
# Trying removal of: Street 953632964.1792
# Trying removal of: Lot Shape 952784665.3726
# Trying removal of: Land Contour 953577876.901
# Trying removal of: Utilities 949710234.5684
# Trying removal of: Lot Config 951795924.9423
# Trying removal of: Land Slope 953924304.9846
# Trying removal of: Neighborhood 955598642.3698
# Trying removal of: Condition 1 951545060.0423
# Trying removal of: Condition 2 951564585.9959
# Trying removal of: Bldg Type 953900218.6125
# Trying removal of: House Style 954198848.5412
# Trying removal of: Overall Qual 1055357736.7003
# Trying removal of: Overall Cond 964273451.03
# Trying removal of: Year Built 957278384.086
# Trying removal of: Year Remod/Add 951816595.7506
# Trying removal of: Roof Style 954062046.0712
# Trying removal of: Exterior 1st 955691961.8044
# Trying removal of: Exterior 2nd 952035966.6672
# Trying removal of: Mas Vnr Area 961296652.5262
# Trying removal of: Exter Qual 977726470.1771
# Trying removal of: Exter Cond 952148940.6902
# Trying removal of: Foundation 952352167.6322
# Trying removal of: Bsmt Qual 967142367.377
# Trying removal of: Bsmt Cond 952743046.4984
# Trying removal of: Bsmt Exposure 968133135.2858
# Trying removal of: BsmtFin Type 1 954120457.175
# Trying removal of: BsmtFin SF 1 952393566.1373
# Trying removal of: BsmtFin Type 2 951149680.6305
# Trying removal of: BsmtFin SF 2 952400204.7361
# Trying removal of: Bsmt Unf SF 952409024.7451
# Trying removal of: Total Bsmt SF 952409356.5211
# Trying removal of: Heating 951301032.6607
# Trying removal of: Heating QC 953401625.6631
# Trying removal of: Central Air 951966311.8925
# Trying removal of: Electrical 952237388.5083
# Trying removal of: 1st Flr SF 952416525.7479
# Trying removal of: 2nd Flr SF 952416525.7479
# Trying removal of: Low Qual Fin SF 952416525.7478
# Trying removal of: Gr Liv Area 952416525.7478
# Trying removal of: Bsmt Full Bath 958599548.4433
# Trying removal of: Bsmt Half Bath 950224295.9959
# Trying removal of: Full Bath 950500002.4684
# Trying removal of: Half Bath 951866129.3302
# Trying removal of: Kitchen AbvGr 953817516.3604
# Trying removal of: Kitchen Qual 965273790.5228
# Trying removal of: TotRms AbvGrd 950889302.8762
# Trying removal of: Functional 961043047.5097
# Trying removal of: Fireplaces 958831894.4624
# Trying removal of: Garage Type 951970467.5017
# Trying removal of: Garage Yr Blt 952945558.943
# Trying removal of: Garage Finish 951016778.2705
# Trying removal of: Garage Cars 964186717.1659
# Trying removal of: Garage Qual 952996077.6423
# Trying removal of: Garage Cond 953375650.0521
# Trying removal of: Paved Drive 951874475.9162
# Trying removal of: Wood Deck SF 954966254.0726
# Trying removal of: Open Porch SF 950810218.3358
# Trying removal of: Enclosed Porch 953274359.7445
# Trying removal of: 3Ssn Porch 951404857.2404
# Trying removal of: Screen Porch 967049306.3584
# Trying removal of: Mo Sold 951294114.1526
# Trying removal of: Yr Sold 956152722.7645
# Trying removal of: Sale Type 952302384.3612
# Trying removal of: Sale Condition 960964423.3996
#
# Removing Utilities:  CV score (MSE) 949710234.5684
#
# Round 8:
# Trying removal of: MS SubClass 953548321.7645
# Trying removal of: MS Zoning 949623289.4384
# Trying removal of: Lot Area 953965898.2944
# Trying removal of: Street 952727300.0841
# Trying removal of: Lot Shape 950098476.7085
# Trying removal of: Land Contour 950763109.1979
# Trying removal of: Lot Config 949097066.5957
# Trying removal of: Land Slope 951322215.9527
# Trying removal of: Neighborhood 952879548.3206
# Trying removal of: Condition 1 948860579.0565
# Trying removal of: Condition 2 948866921.8875
# Trying removal of: Bldg Type 951183474.8704
# Trying removal of: House Style 951729354.7653
# Trying removal of: Overall Qual 1053286097.6072
# Trying removal of: Overall Cond 961376669.7651
# Trying removal of: Year Built 954839760.2084
# Trying removal of: Year Remod/Add 949127186.4131
# Trying removal of: Roof Style 951520159.3307
# Trying removal of: Exterior 1st 953131488.6746
# Trying removal of: Exterior 2nd 949243962.3027
# Trying removal of: Mas Vnr Area 958574971.9898
# Trying removal of: Exter Qual 973341640.6385
# Trying removal of: Exter Cond 949568866.8216
# Trying removal of: Foundation 949640959.7209
# Trying removal of: Bsmt Qual 964328099.3372
# Trying removal of: Bsmt Cond 949909523.8386
# Trying removal of: Bsmt Exposure 965426518.5083
# Trying removal of: BsmtFin Type 1 951287241.4117
# Trying removal of: BsmtFin SF 1 949690499.1599
# Trying removal of: BsmtFin Type 2 948444201.5706
# Trying removal of: BsmtFin SF 2 949695989.1146
# Trying removal of: Bsmt Unf SF 949703568.9565
# Trying removal of: Total Bsmt SF 949701276.6013
# Trying removal of: Heating 948501868.7833
# Trying removal of: Heating QC 950759359.7985
# Trying removal of: Central Air 949262627.9866
# Trying removal of: Electrical 949566325.7899
# Trying removal of: 1st Flr SF 949710234.5684
# Trying removal of: 2nd Flr SF 949710234.5685
# Trying removal of: Low Qual Fin SF 949710234.5686
# Trying removal of: Gr Liv Area 949710234.5685
# Trying removal of: Bsmt Full Bath 955983051.797
# Trying removal of: Bsmt Half Bath 947448920.3012
# Trying removal of: Full Bath 947891459.4931
# Trying removal of: Half Bath 949260686.2956
# Trying removal of: Kitchen AbvGr 951126222.3215
# Trying removal of: Kitchen Qual 963088523.52
# Trying removal of: TotRms AbvGrd 948101603.276
# Trying removal of: Functional 958575002.5755
# Trying removal of: Fireplaces 956483869.3327
# Trying removal of: Garage Type 949096319.5359
# Trying removal of: Garage Yr Blt 950074011.9318
# Trying removal of: Garage Finish 948326284.4557
# Trying removal of: Garage Cars 961693303.9154
# Trying removal of: Garage Qual 950251378.939
# Trying removal of: Garage Cond 950601165.6585
# Trying removal of: Paved Drive 949170400.2243
# Trying removal of: Wood Deck SF 952143393.5472
# Trying removal of: Open Porch SF 948117482.4331
# Trying removal of: Enclosed Porch 950675774.9651
# Trying removal of: 3Ssn Porch 948700914.7639
# Trying removal of: Screen Porch 964476864.9815
# Trying removal of: Mo Sold 948609192.8498
# Trying removal of: Yr Sold 953398669.7084
# Trying removal of: Sale Type 949528677.9551
# Trying removal of: Sale Condition 957782970.8719
#
# Removing Bsmt Half Bath:  CV score (MSE) 947448920.3012
#
# Round 9:
# Trying removal of: MS SubClass 951182775.8948
# Trying removal of: MS Zoning 947363159.4114
# Trying removal of: Lot Area 951594536.0124
# Trying removal of: Street 950413938.8865
# Trying removal of: Lot Shape 947843841.9487
# Trying removal of: Land Contour 948430550.0077
# Trying removal of: Lot Config 946909882.9481
# Trying removal of: Land Slope 949119272.1288
# Trying removal of: Neighborhood 950517305.1524
# Trying removal of: Condition 1 946680154.3457
# Trying removal of: Condition 2 946562275.8128
# Trying removal of: Bldg Type 948965773.6802
# Trying removal of: House Style 950092475.5433
# Trying removal of: Overall Qual 1050952603.5213
# Trying removal of: Overall Cond 958998788.4786
# Trying removal of: Year Built 952541802.9875
# Trying removal of: Year Remod/Add 946886867.4235
# Trying removal of: Roof Style 949310343.115
# Trying removal of: Exterior 1st 950821607.8541
# Trying removal of: Exterior 2nd 946947138.2168
# Trying removal of: Mas Vnr Area 956273008.6544
# Trying removal of: Exter Qual 971054424.1693
# Trying removal of: Exter Cond 947381913.9116
# Trying removal of: Foundation 947365105.9029
# Trying removal of: Bsmt Qual 962068160.9349
# Trying removal of: Bsmt Cond 947645777.6622
# Trying removal of: Bsmt Exposure 963149798.2678
# Trying removal of: BsmtFin Type 1 948854401.025
# Trying removal of: BsmtFin SF 1 947438467.9946
# Trying removal of: BsmtFin Type 2 946422598.2341
# Trying removal of: BsmtFin SF 2 947441369.861
# Trying removal of: Bsmt Unf SF 947449803.3406
# Trying removal of: Total Bsmt SF 947446588.4001
# Trying removal of: Heating 946251652.9445
# Trying removal of: Heating QC 948551972.2238
# Trying removal of: Central Air 947020787.4871
# Trying removal of: Electrical 947311517.693
# Trying removal of: 1st Flr SF 947448920.301
# Trying removal of: 2nd Flr SF 947448920.301
# Trying removal of: Low Qual Fin SF 947448920.3012
# Trying removal of: Gr Liv Area 947448920.3012
# Trying removal of: Bsmt Full Bath 954449899.3886
# Trying removal of: Full Bath 945719093.5419
# Trying removal of: Half Bath 946938618.2104
# Trying removal of: Kitchen AbvGr 948851089.2945
# Trying removal of: Kitchen Qual 960924378.6071
# Trying removal of: TotRms AbvGrd 945928678.4035
# Trying removal of: Functional 956228836.3955
# Trying removal of: Fireplaces 953919617.0751
# Trying removal of: Garage Type 946970675.2167
# Trying removal of: Garage Yr Blt 947864945.752
# Trying removal of: Garage Finish 946013454.2468
# Trying removal of: Garage Cars 959413046.4254
# Trying removal of: Garage Qual 948054333.086
# Trying removal of: Garage Cond 948439164.267
# Trying removal of: Paved Drive 946870673.5206
# Trying removal of: Wood Deck SF 949745646.6875
# Trying removal of: Open Porch SF 945812342.5321
# Trying removal of: Enclosed Porch 948428289.0682
# Trying removal of: 3Ssn Porch 946408407.727
# Trying removal of: Screen Porch 961823424.9324
# Trying removal of: Mo Sold 946493096.4837
# Trying removal of: Yr Sold 950913213.1386
# Trying removal of: Sale Type 947393954.4423
# Trying removal of: Sale Condition 955848696.0205
#
# Removing Full Bath:  CV score (MSE) 945719093.5419
#
# Round 10:
# Trying removal of: MS SubClass 949396394.9972
# Trying removal of: MS Zoning 945869004.0396
# Trying removal of: Lot Area 950109351.1596
# Trying removal of: Street 948604222.9424
# Trying removal of: Lot Shape 946087068.7087
# Trying removal of: Land Contour 946824146.898
# Trying removal of: Lot Config 945122146.6358
# Trying removal of: Land Slope 947596594.9729
# Trying removal of: Neighborhood 948698398.2661
# Trying removal of: Condition 1 944969076.1322
# Trying removal of: Condition 2 944799618.3961
# Trying removal of: Bldg Type 947162611.6394
# Trying removal of: House Style 948377245.0338
# Trying removal of: Overall Qual 1050348998.7554
# Trying removal of: Overall Cond 957243924.7381
# Trying removal of: Year Built 951835558.0649
# Trying removal of: Year Remod/Add 945296639.1498
# Trying removal of: Roof Style 947605909.3615
# Trying removal of: Exterior 1st 949195574.3023
# Trying removal of: Exterior 2nd 945308461.2931
# Trying removal of: Mas Vnr Area 954045012.7428
# Trying removal of: Exter Qual 968738555.9255
# Trying removal of: Exter Cond 945416373.4564
# Trying removal of: Foundation 945641758.4072
# Trying removal of: Bsmt Qual 960562444.3587
# Trying removal of: Bsmt Cond 945781022.0474
# Trying removal of: Bsmt Exposure 960957668.5972
# Trying removal of: BsmtFin Type 1 947115249.9865
# Trying removal of: BsmtFin SF 1 945712602.7776
# Trying removal of: BsmtFin Type 2 944682874.6107
# Trying removal of: BsmtFin SF 2 945715026.9834
# Trying removal of: Bsmt Unf SF 945725726.416
# Trying removal of: Total Bsmt SF 945724275.631
# Trying removal of: Heating 944422724.3866
# Trying removal of: Heating QC 946813214.1658
# Trying removal of: Central Air 945337054.5763
# Trying removal of: Electrical 945577649.3395
# Trying removal of: 1st Flr SF 945719093.5422
# Trying removal of: 2nd Flr SF 945719093.5419
# Trying removal of: Low Qual Fin SF 945719093.542
# Trying removal of: Gr Liv Area 945719093.5423
# Trying removal of: Bsmt Full Bath 952621817.5397
# Trying removal of: Half Bath 945939282.2604
# Trying removal of: Kitchen AbvGr 946672369.562
# Trying removal of: Kitchen Qual 959387888.6596
# Trying removal of: TotRms AbvGrd 944259893.7311
# Trying removal of: Functional 954583856.1526
# Trying removal of: Fireplaces 952335817.6179
# Trying removal of: Garage Type 945029414.7063
# Trying removal of: Garage Yr Blt 946299693.5944
# Trying removal of: Garage Finish 944317845.9515
# Trying removal of: Garage Cars 957690499.3742
# Trying removal of: Garage Qual 946369397.0661
# Trying removal of: Garage Cond 946751381.2444
# Trying removal of: Paved Drive 945192679.0297
# Trying removal of: Wood Deck SF 947968448.0962
# Trying removal of: Open Porch SF 944161766.2379
# Trying removal of: Enclosed Porch 946693038.451
# Trying removal of: 3Ssn Porch 944689707.7902
# Trying removal of: Screen Porch 960102205.6208
# Trying removal of: Mo Sold 944777862.7496
# Trying removal of: Yr Sold 949097597.4214
# Trying removal of: Sale Type 945521478.2702
# Trying removal of: Sale Condition 954187340.6568
#
# Removing Open Porch SF:  CV score (MSE) 944161766.2379
#
# Round 11:
# Trying removal of: MS SubClass 947787142.2379
# Trying removal of: MS Zoning 944123632.6669
# Trying removal of: Lot Area 948496126.9518
# Trying removal of: Street 947101012.3795
# Trying removal of: Lot Shape 944527697.6603
# Trying removal of: Land Contour 945203330.0374
# Trying removal of: Lot Config 943605047.6542
# Trying removal of: Land Slope 945938029.7113
# Trying removal of: Neighborhood 946971183.0909
# Trying removal of: Condition 1 943405899.0396
# Trying removal of: Condition 2 943241086.9218
# Trying removal of: Bldg Type 945651218.4068
# Trying removal of: House Style 947104495.7135
# Trying removal of: Overall Qual 1047407573.5261
# Trying removal of: Overall Cond 955734686.3454
# Trying removal of: Year Built 950570869.9693
# Trying removal of: Year Remod/Add 943695515.0393
# Trying removal of: Roof Style 946007900.8617
# Trying removal of: Exterior 1st 947749183.442
# Trying removal of: Exterior 2nd 943687614.1325
# Trying removal of: Mas Vnr Area 952792578.1952
# Trying removal of: Exter Qual 966264055.4626
# Trying removal of: Exter Cond 943987703.6381
# Trying removal of: Foundation 944064094.9143
# Trying removal of: Bsmt Qual 959550003.7199
# Trying removal of: Bsmt Cond 944311530.5893
# Trying removal of: Bsmt Exposure 959403291.072
# Trying removal of: BsmtFin Type 1 945612784.6602
# Trying removal of: BsmtFin SF 1 944157792.5946
# Trying removal of: BsmtFin Type 2 943064957.3898
# Trying removal of: BsmtFin SF 2 944159723.3232
# Trying removal of: Bsmt Unf SF 944170644.1663
# Trying removal of: Total Bsmt SF 944167000.4178
# Trying removal of: Heating 942765659.6226
# Trying removal of: Heating QC 945395142.0733
# Trying removal of: Central Air 943729530.88
# Trying removal of: Electrical 944000710.3826
# Trying removal of: 1st Flr SF 944161766.2379
# Trying removal of: 2nd Flr SF 944161766.2378
# Trying removal of: Low Qual Fin SF 944161766.2378
# Trying removal of: Gr Liv Area 944161766.238
# Trying removal of: Bsmt Full Bath 951336164.3294
# Trying removal of: Half Bath 944446063.4794
# Trying removal of: Kitchen AbvGr 944865521.9998
# Trying removal of: Kitchen Qual 958321485.346
# Trying removal of: TotRms AbvGrd 942686300.6229
# Trying removal of: Functional 952805667.5272
# Trying removal of: Fireplaces 950539883.6961
# Trying removal of: Garage Type 943594363.1469
# Trying removal of: Garage Yr Blt 944594420.5164
# Trying removal of: Garage Finish 942726903.8003
# Trying removal of: Garage Cars 956444299.1709
# Trying removal of: Garage Qual 944804960.9808
# Trying removal of: Garage Cond 945214921.643
# Trying removal of: Paved Drive 943643914.1097
# Trying removal of: Wood Deck SF 946690159.7628
# Trying removal of: Enclosed Porch 945281336.64
# Trying removal of: 3Ssn Porch 943176259.5647
# Trying removal of: Screen Porch 958408699.3826
# Trying removal of: Mo Sold 943144820.5492
# Trying removal of: Yr Sold 947418578.6029
# Trying removal of: Sale Type 943952180.3361
# Trying removal of: Sale Condition 952839344.0076
#
# Removing TotRms AbvGrd:  CV score (MSE) 942686300.6229
#
# Round 12:
# Trying removal of: MS SubClass 946313362.6729
# Trying removal of: MS Zoning 942612011.5607
# Trying removal of: Lot Area 946986092.6913
# Trying removal of: Street 945611075.8336
# Trying removal of: Lot Shape 943051527.5682
# Trying removal of: Land Contour 943731109.1958
# Trying removal of: Lot Config 942077097.7094
# Trying removal of: Land Slope 944390431.3553
# Trying removal of: Neighborhood 945478712.9624
# Trying removal of: Condition 1 941843547.9625
# Trying removal of: Condition 2 941748316.9181
# Trying removal of: Bldg Type 944284093.1231
# Trying removal of: House Style 945724778.8283
# Trying removal of: Overall Qual 1045946574.1519
# Trying removal of: Overall Cond 954269274.0263
# Trying removal of: Year Built 948879767.4787
# Trying removal of: Year Remod/Add 942214978.2407
# Trying removal of: Roof Style 944460770.1032
# Trying removal of: Exterior 1st 946136906.3766
# Trying removal of: Exterior 2nd 942167498.9946
# Trying removal of: Mas Vnr Area 951403327.2187
# Trying removal of: Exter Qual 964971814.7359
# Trying removal of: Exter Cond 942576493.005
# Trying removal of: Foundation 942604419.9961
# Trying removal of: Bsmt Qual 957944726.9181
# Trying removal of: Bsmt Cond 942889800.0555
# Trying removal of: Bsmt Exposure 958011386.8586
# Trying removal of: BsmtFin Type 1 944155660.6857
# Trying removal of: BsmtFin SF 1 942686438.3353
# Trying removal of: BsmtFin Type 2 941606122.2317
# Trying removal of: BsmtFin SF 2 942686485.0088
# Trying removal of: Bsmt Unf SF 942698122.0866
# Trying removal of: Total Bsmt SF 942691509.6784
# Trying removal of: Heating 941389551.1241
# Trying removal of: Heating QC 943974907.9155
# Trying removal of: Central Air 942237671.8086
# Trying removal of: Electrical 942526937.7673
# Trying removal of: 1st Flr SF 942686300.6228
# Trying removal of: 2nd Flr SF 942686300.623
# Trying removal of: Low Qual Fin SF 942686300.6229
# Trying removal of: Gr Liv Area 942686300.6229
# Trying removal of: Bsmt Full Bath 949882968.0498
# Trying removal of: Half Bath 942934547.5391
# Trying removal of: Kitchen AbvGr 943144294.3439
# Trying removal of: Kitchen Qual 956606388.7686
# Trying removal of: Functional 951074811.4378
# Trying removal of: Fireplaces 949090009.7194
# Trying removal of: Garage Type 942169909.0797
# Trying removal of: Garage Yr Blt 943149196.1353
# Trying removal of: Garage Finish 941232588.5541
# Trying removal of: Garage Cars 954806434.9162
# Trying removal of: Garage Qual 943378877.7118
# Trying removal of: Garage Cond 943729407.8623
# Trying removal of: Paved Drive 942198865.0683
# Trying removal of: Wood Deck SF 945128134.9488
# Trying removal of: Enclosed Porch 943771910.5387
# Trying removal of: 3Ssn Porch 941696537.6242
# Trying removal of: Screen Porch 956955447.9794
# Trying removal of: Mo Sold 941712201.8357
# Trying removal of: Yr Sold 946042975.3103
# Trying removal of: Sale Type 942500507.7056
# Trying removal of: Sale Condition 951262381.1441
#
# Removing Garage Finish:  CV score (MSE) 941232588.5541
#
# Round 13:
# Trying removal of: MS SubClass 944975351.8516
# Trying removal of: MS Zoning 941152683.512
# Trying removal of: Lot Area 945697493.7218
# Trying removal of: Street 944244233.5858
# Trying removal of: Lot Shape 941647098.1659
# Trying removal of: Land Contour 942367626.4919
# Trying removal of: Lot Config 940610349.5645
# Trying removal of: Land Slope 942827104.4309
# Trying removal of: Neighborhood 943839632.3749
# Trying removal of: Condition 1 940364433.7952
# Trying removal of: Condition 2 940276604.9948
# Trying removal of: Bldg Type 942746519.6896
# Trying removal of: House Style 944253851.8996
# Trying removal of: Overall Qual 1044936050.5088
# Trying removal of: Overall Cond 952803673.6668
# Trying removal of: Year Built 947695591.2036
# Trying removal of: Year Remod/Add 940696152.2154
# Trying removal of: Roof Style 943201510.0324
# Trying removal of: Exterior 1st 944772996.3268
# Trying removal of: Exterior 2nd 940721163.9769
# Trying removal of: Mas Vnr Area 949992328.6787
# Trying removal of: Exter Qual 964061092.8805
# Trying removal of: Exter Cond 941136850.9767
# Trying removal of: Foundation 941154837.1105
# Trying removal of: Bsmt Qual 956782425.5799
# Trying removal of: Bsmt Cond 941481135.4831
# Trying removal of: Bsmt Exposure 956335221.6426
# Trying removal of: BsmtFin Type 1 942628380.525
# Trying removal of: BsmtFin SF 1 941233427.0464
# Trying removal of: BsmtFin Type 2 940204011.4982
# Trying removal of: BsmtFin SF 2 941233581.1768
# Trying removal of: Bsmt Unf SF 941245058.258
# Trying removal of: Total Bsmt SF 941238804.703
# Trying removal of: Heating 939968774.1117
# Trying removal of: Heating QC 942705837.7015
# Trying removal of: Central Air 940790890.3149
# Trying removal of: Electrical 941028294.0109
# Trying removal of: 1st Flr SF 941232588.5542
# Trying removal of: 2nd Flr SF 941232588.5541
# Trying removal of: Low Qual Fin SF 941232588.5541
# Trying removal of: Gr Liv Area 941232588.5542
# Trying removal of: Bsmt Full Bath 948564586.2743
# Trying removal of: Half Bath 941474677.5848
# Trying removal of: Kitchen AbvGr 941818442.3801
# Trying removal of: Kitchen Qual 955235218.6067
# Trying removal of: Functional 949675969.6607
# Trying removal of: Fireplaces 948382119.601
# Trying removal of: Garage Type 940680517.4545
# Trying removal of: Garage Yr Blt 941761893.443
# Trying removal of: Garage Cars 954351314.424
# Trying removal of: Garage Qual 941927571.1565
# Trying removal of: Garage Cond 942193970.67
# Trying removal of: Paved Drive 940734519.5158
# Trying removal of: Wood Deck SF 943614685.1311
# Trying removal of: Enclosed Porch 942240437.003
# Trying removal of: 3Ssn Porch 940270986.8079
# Trying removal of: Screen Porch 955363189.3081
# Trying removal of: Mo Sold 940255999.2892
# Trying removal of: Yr Sold 944674757.6637
# Trying removal of: Sale Type 941082850.07
# Trying removal of: Sale Condition 949987331.1983
#
# Removing Heating:  CV score (MSE) 939968774.1117
#
# Round 14:
# Trying removal of: MS SubClass 943964339.406
# Trying removal of: MS Zoning 939980951.4986
# Trying removal of: Lot Area 943721339.6636
# Trying removal of: Street 943033812.2576
# Trying removal of: Lot Shape 940411834.8959
# Trying removal of: Land Contour 940913876.1548
# Trying removal of: Lot Config 939251075.7775
# Trying removal of: Land Slope 941773060.604
# Trying removal of: Neighborhood 942525594.2575
# Trying removal of: Condition 1 939077002.2382
# Trying removal of: Condition 2 939100342.0055
# Trying removal of: Bldg Type 941498065.3859
# Trying removal of: House Style 942521409.9954
# Trying removal of: Overall Qual 1041540677.8761
# Trying removal of: Overall Cond 952066138.3913
# Trying removal of: Year Built 946325354.2222
# Trying removal of: Year Remod/Add 939429146.4203
# Trying removal of: Roof Style 942096916.4781
# Trying removal of: Exterior 1st 943820714.9972
# Trying removal of: Exterior 2nd 939568825.383
# Trying removal of: Mas Vnr Area 948519504.1022
# Trying removal of: Exter Qual 963443165.9065
# Trying removal of: Exter Cond 939871766.8823
# Trying removal of: Foundation 939830422.9067
# Trying removal of: Bsmt Qual 955377345.2064
# Trying removal of: Bsmt Cond 940139376.8454
# Trying removal of: Bsmt Exposure 954935981.855
# Trying removal of: BsmtFin Type 1 941288259.3231
# Trying removal of: BsmtFin SF 1 939966368.4901
# Trying removal of: BsmtFin Type 2 938951668.2124
# Trying removal of: BsmtFin SF 2 939967151.4396
# Trying removal of: Bsmt Unf SF 939977722.4583
# Trying removal of: Total Bsmt SF 939971850.851
# Trying removal of: Heating QC 941244871.7373
# Trying removal of: Central Air 939519260.4053
# Trying removal of: Electrical 939743469.0937
# Trying removal of: 1st Flr SF 939968774.1118
# Trying removal of: 2nd Flr SF 939968774.1114
# Trying removal of: Low Qual Fin SF 939968774.1118
# Trying removal of: Gr Liv Area 939968774.1118
# Trying removal of: Bsmt Full Bath 947281230.7454
# Trying removal of: Half Bath 940213229.4467
# Trying removal of: Kitchen AbvGr 940695476.4967
# Trying removal of: Kitchen Qual 954193041.5114
# Trying removal of: Functional 948354926.7874
# Trying removal of: Fireplaces 947441263.8707
# Trying removal of: Garage Type 939348381.6448
# Trying removal of: Garage Yr Blt 940692051.2006
# Trying removal of: Garage Cars 953304278.4066
# Trying removal of: Garage Qual 940778450.051
# Trying removal of: Garage Cond 940611321.8545
# Trying removal of: Paved Drive 939439734.7345
# Trying removal of: Wood Deck SF 942333834.8352
# Trying removal of: Enclosed Porch 941003769.2371
# Trying removal of: 3Ssn Porch 938991216.5024
# Trying removal of: Screen Porch 953878832.5698
# Trying removal of: Mo Sold 939019546.7905
# Trying removal of: Yr Sold 943517856.9058
# Trying removal of: Sale Type 939838672.6653
# Trying removal of: Sale Condition 948525469.2858
#
# Removing BsmtFin Type 2:  CV score (MSE) 938951668.2124
#
# Round 15:
# Trying removal of: MS SubClass 943022845.3749
# Trying removal of: MS Zoning 938971891.0763
# Trying removal of: Lot Area 942648790.8027
# Trying removal of: Street 942033337.4253
# Trying removal of: Lot Shape 939382061.495
# Trying removal of: Land Contour 939903339.3622
# Trying removal of: Lot Config 938271292.1488
# Trying removal of: Land Slope 940674905.0972
# Trying removal of: Neighborhood 941464024.4617
# Trying removal of: Condition 1 938134036.241
# Trying removal of: Condition 2 938089092.3727
# Trying removal of: Bldg Type 940436321.5572
# Trying removal of: House Style 941555631.6421
# Trying removal of: Overall Qual 1039994052.5924
# Trying removal of: Overall Cond 950854225.6453
# Trying removal of: Year Built 945241374.9352
# Trying removal of: Year Remod/Add 938402667.4716
# Trying removal of: Roof Style 941177368.4343
# Trying removal of: Exterior 1st 942755262.33
# Trying removal of: Exterior 2nd 938509545.5351
# Trying removal of: Mas Vnr Area 947482776.0753
# Trying removal of: Exter Qual 962363407.9492
# Trying removal of: Exter Cond 938900311.0677
# Trying removal of: Foundation 938819264.9198
# Trying removal of: Bsmt Qual 954521743.1564
# Trying removal of: Bsmt Cond 939158149.5079
# Trying removal of: Bsmt Exposure 954082404.7042
# Trying removal of: BsmtFin Type 1 940408196.2873
# Trying removal of: BsmtFin SF 1 938949531.0455
# Trying removal of: BsmtFin SF 2 938951595.0979
# Trying removal of: Bsmt Unf SF 938960958.1268
# Trying removal of: Total Bsmt SF 938955090.2494
# Trying removal of: Heating QC 940316571.8942
# Trying removal of: Central Air 938447958.1476
# Trying removal of: Electrical 938688345.0351
# Trying removal of: 1st Flr SF 938951668.2123
# Trying removal of: 2nd Flr SF 938951668.2126
# Trying removal of: Low Qual Fin SF 938951668.2123
# Trying removal of: Gr Liv Area 938951668.2123
# Trying removal of: Bsmt Full Bath 946059736.4779
# Trying removal of: Half Bath 939194210.3629
# Trying removal of: Kitchen AbvGr 939671891.016
# Trying removal of: Kitchen Qual 953047206.5764
# Trying removal of: Functional 947476310.4915
# Trying removal of: Fireplaces 946447836.8995
# Trying removal of: Garage Type 938335277.3871
# Trying removal of: Garage Yr Blt 939695128.5274
# Trying removal of: Garage Cars 952455146.985
# Trying removal of: Garage Qual 939780638.6728
# Trying removal of: Garage Cond 939631916.628
# Trying removal of: Paved Drive 938431791.3063
# Trying removal of: Wood Deck SF 941347466.7532
# Trying removal of: Enclosed Porch 939951388.0601
# Trying removal of: 3Ssn Porch 938077372.3512
# Trying removal of: Screen Porch 953118633.4139
# Trying removal of: Mo Sold 938076946.3822
# Trying removal of: Yr Sold 942577036.9746
# Trying removal of: Sale Type 938844121.1249
# Trying removal of: Sale Condition 947214088.3979
#
# Removing Mo Sold:  CV score (MSE) 938076946.3822
#
# Round 16:
# Trying removal of: MS SubClass 942050153.7763
# Trying removal of: MS Zoning 938121186.4896
# Trying removal of: Lot Area 941731489.8999
# Trying removal of: Street 941199879.6863
# Trying removal of: Lot Shape 938512795.787
# Trying removal of: Land Contour 939082134.3042
# Trying removal of: Lot Config 937393313.0771
# Trying removal of: Land Slope 939794326.6037
# Trying removal of: Neighborhood 940534225.3875
# Trying removal of: Condition 1 937249503.2005
# ...
# Trying removal of: Neighborhood 927250851.9369
# Trying removal of: House Style 928461106.3708
# Trying removal of: Overall Qual 1025761248.9421
# Trying removal of: Overall Cond 940409890.442
# Trying removal of: Year Built 945617353.8106
# Trying removal of: Mas Vnr Area 934576482.9942
# Trying removal of: Exter Qual 951989528.6633
# Trying removal of: Bsmt Qual 939368062.3579
# Trying removal of: Bsmt Exposure 943884469.6752
# Trying removal of: BsmtFin Type 1 929010551.2737
# Trying removal of: Gr Liv Area 1249310064.4147
# Trying removal of: Bsmt Full Bath 944830200.5193
# Trying removal of: Kitchen AbvGr 925550622.689
# Trying removal of: Kitchen Qual 939681786.2131
# Trying removal of: Functional 930768900.097
# Trying removal of: Fireplaces 930838144.3274
# Trying removal of: Garage Cars 940335726.5132
# Trying removal of: Wood Deck SF 925114897.687
# Trying removal of: Screen Porch 938917235.6765
# Trying removal of: Yr Sold 926755669.0585
# Trying removal of: Sale Condition 928983776.8751
#
# Removing Wood Deck SF:  CV score (MSE) 925114897.687
#
# Round 51:
# Trying removal of: MS SubClass 961118124.4332
# Trying removal of: Lot Area 939097188.9292
# Trying removal of: Street 927752536.1428
# Trying removal of: Neighborhood 929626743.8962
# Trying removal of: House Style 930970017.2456
# Trying removal of: Overall Qual 1027569657.3028
# Trying removal of: Overall Cond 944713052.9424
# Trying removal of: Year Built 950051334.8598
# Trying removal of: Mas Vnr Area 936870931.5723
# Trying removal of: Exter Qual 954005960.177
# Trying removal of: Bsmt Qual 942401501.6444
# Trying removal of: Bsmt Exposure 948156040.3825
# Trying removal of: BsmtFin Type 1 931820230.2243
# Trying removal of: Gr Liv Area 1264859288.4337
# Trying removal of: Bsmt Full Bath 948326018.564
# Trying removal of: Kitchen AbvGr 928385487.3668
# Trying removal of: Kitchen Qual 942351317.2355
# Trying removal of: Functional 932689904.7599
# Trying removal of: Fireplaces 934178132.8229
# Trying removal of: Garage Cars 943181898.1379
# Trying removal of: Screen Porch 940187557.9309
# Trying removal of: Yr Sold 928965741.2367
# Trying removal of: Sale Condition 931360216.311
#
# Removing Street:  CV score (MSE) 927752536.1428
#
# Round 52:
# Trying removal of: MS SubClass 964914846.5
# Trying removal of: Lot Area 939410156.7476
# Trying removal of: Neighborhood 932244956.3566
# Trying removal of: House Style 933815584.3304
# Trying removal of: Overall Qual 1031780988.9629
# Trying removal of: Overall Cond 947668644.7267
# Trying removal of: Year Built 954111320.3724
# Trying removal of: Mas Vnr Area 939415849.4911
# Trying removal of: Exter Qual 954643374.8644
# Trying removal of: Bsmt Qual 944799958.1014
# Trying removal of: Bsmt Exposure 950233423.2264
# Trying removal of: BsmtFin Type 1 934663829.5582
# Trying removal of: Gr Liv Area 1277449303.9532
# Trying removal of: Bsmt Full Bath 950856978.0616
# Trying removal of: Kitchen AbvGr 930900712.3952
# Trying removal of: Kitchen Qual 945386311.564
# Trying removal of: Functional 935749928.7898
# Trying removal of: Fireplaces 936990476.9132
# Trying removal of: Garage Cars 945526947.2147
# Trying removal of: Screen Porch 942592154.8393
# Trying removal of: Yr Sold 931859473.3579
# Trying removal of: Sale Condition 934161311.3573
#
# Removing Kitchen AbvGr:  CV score (MSE) 930900712.3952
#
# Round 53:
# Trying removal of: MS SubClass 977722587.0576
# Trying removal of: Lot Area 942724072.5407
# Trying removal of: Neighborhood 934786957.8176
# Trying removal of: House Style 935911315.3179
# Trying removal of: Overall Qual 1043822419.2604
# Trying removal of: Overall Cond 952038244.2983
# Trying removal of: Year Built 957065557.1863
# Trying removal of: Mas Vnr Area 942813532.6377
# Trying removal of: Exter Qual 957309901.9394
# Trying removal of: Bsmt Qual 949564919.9435
# Trying removal of: Bsmt Exposure 953074490.4728
# Trying removal of: BsmtFin Type 1 938626365.2555
# Trying removal of: Gr Liv Area 1290352462.5487
# Trying removal of: Bsmt Full Bath 953067912.097
# Trying removal of: Kitchen Qual 949724374.7278
# Trying removal of: Functional 938297923.3992
# Trying removal of: Fireplaces 941285998.7942
# Trying removal of: Garage Cars 948079840.1113
# Trying removal of: Screen Porch 946455544.9458
# Trying removal of: Yr Sold 935388225.3152
# Trying removal of: Sale Condition 937631425.493
#
# Removing Neighborhood:  CV score (MSE) 934786957.8176
#
# Round 54:
# Trying removal of: MS SubClass 981354003.2036
# Trying removal of: Lot Area 947097346.2847
# Trying removal of: House Style 939536876.474
# Trying removal of: Overall Qual 1051850509.9508
# Trying removal of: Overall Cond 955227789.2747
# Trying removal of: Year Built 959165328.95
# Trying removal of: Mas Vnr Area 947346494.5723
# Trying removal of: Exter Qual 962609738.0624
# Trying removal of: Bsmt Qual 953992518.1309
# Trying removal of: Bsmt Exposure 955085350.3392
# Trying removal of: BsmtFin Type 1 943445959.1171
# Trying removal of: Gr Liv Area 1294445563.2647
# Trying removal of: Bsmt Full Bath 957900239.0835
# Trying removal of: Kitchen Qual 953611740.7165
# Trying removal of: Functional 942295331.6757
# Trying removal of: Fireplaces 944092451.7959
# Trying removal of: Garage Cars 953301863.6584
# Trying removal of: Screen Porch 950240807.109
# Trying removal of: Yr Sold 939057619.0618
# Trying removal of: Sale Condition 941223909.2807
#
# Removing Yr Sold:  CV score (MSE) 939057619.0618
#
# Round 55:
# Trying removal of: MS SubClass 984705018.1578
# Trying removal of: Lot Area 951647592.0368
# Trying removal of: House Style 943865703.147
# Trying removal of: Overall Qual 1055964713.7035
# Trying removal of: Overall Cond 958873154.0061
# Trying removal of: Year Built 963416942.5817
# Trying removal of: Mas Vnr Area 951799207.3837
# Trying removal of: Exter Qual 965528745.6933
# Trying removal of: Bsmt Qual 958169644.0989
# Trying removal of: Bsmt Exposure 960831106.7444
# Trying removal of: BsmtFin Type 1 947420494.1442
# Trying removal of: Gr Liv Area 1300572989.0589
# Trying removal of: Bsmt Full Bath 960980852.6632
# Trying removal of: Kitchen Qual 958421953.3314
# Trying removal of: Functional 946411926.173
# Trying removal of: Fireplaces 948179230.9473
# Trying removal of: Garage Cars 958027600.7312
# Trying removal of: Screen Porch 954729357.3743
# Trying removal of: Sale Condition 945665638.1106
#
# Removing House Style:  CV score (MSE) 943865703.147
#
# Round 56:
# Trying removal of: MS SubClass 1010752705.8069
# Trying removal of: Lot Area 957241129.2205
# Trying removal of: Overall Qual 1063553413.1368
# Trying removal of: Overall Cond 961561566.563
# Trying removal of: Year Built 964728221.3388
# Trying removal of: Mas Vnr Area 956618401.6914
# Trying removal of: Exter Qual 972860407.3541
# Trying removal of: Bsmt Qual 962306493.7914
# Trying removal of: Bsmt Exposure 963300249.308
# Trying removal of: BsmtFin Type 1 952290968.9899
# Trying removal of: Gr Liv Area 1305166532.5619
# Trying removal of: Bsmt Full Bath 967191356.7853
# Trying removal of: Kitchen Qual 964500022.5595
# Trying removal of: Functional 951084299.485
# Trying removal of: Fireplaces 952777339.1656
# Trying removal of: Garage Cars 962167526.0133
# Trying removal of: Screen Porch 959725685.1938
# Trying removal of: Sale Condition 950743081.7438
#
# Removing Sale Condition:  CV score (MSE) 950743081.7438
#
# Round 57:
# Trying removal of: MS SubClass 1018217271.3564
# Trying removal of: Lot Area 963972991.7332
# Trying removal of: Overall Qual 1071334218.704
# Trying removal of: Overall Cond 972704741.0784
# Trying removal of: Year Built 974755752.0304
# Trying removal of: Mas Vnr Area 963407444.6477
# Trying removal of: Exter Qual 981057792.9274
# Trying removal of: Bsmt Qual 970774965.9013
# Trying removal of: Bsmt Exposure 969385744.8891
# Trying removal of: BsmtFin Type 1 958711896.9711
# Trying removal of: Gr Liv Area 1306355282.8476
# Trying removal of: Bsmt Full Bath 973849825.5052
# Trying removal of: Kitchen Qual 972183654.7676
# Trying removal of: Functional 957772928.6328
# Trying removal of: Fireplaces 960063195.2453
# Trying removal of: Garage Cars 970997044.6511
# Trying removal of: Screen Porch 965613309.894
#
# Removing Functional:  CV score (MSE) 957772928.6328
#
# Round 58:
# Trying removal of: MS SubClass 1024755830.8298
# Trying removal of: Lot Area 970229033.4822
# Trying removal of: Overall Qual 1095177231.0717
# Trying removal of: Overall Cond 983006069.5863
# Trying removal of: Year Built 984766645.7008
# Trying removal of: Mas Vnr Area 971338093.8698
# Trying removal of: Exter Qual 986126367.267
# Trying removal of: Bsmt Qual 977355961.5015
# Trying removal of: Bsmt Exposure 976447704.0145
# Trying removal of: BsmtFin Type 1 965022840.806
# Trying removal of: Gr Liv Area 1305345825.8328
# Trying removal of: Bsmt Full Bath 980804911.194
# Trying removal of: Kitchen Qual 979169866.8018
# Trying removal of: Fireplaces 965614359.2929
# Trying removal of: Garage Cars 976965420.7384
# Trying removal of: Screen Porch 972717875.3534
#
# Removing BsmtFin Type 1:  CV score (MSE) 965022840.806
#
# Round 59:
# Trying removal of: MS SubClass 1031027193.5908
# Trying removal of: Lot Area 977546932.6552
# Trying removal of: Overall Qual 1097081041.4582
# Trying removal of: Overall Cond 995577762.733
# Trying removal of: Year Built 1000422003.7908
# Trying removal of: Mas Vnr Area 980196562.178
# Trying removal of: Exter Qual 992460249.8856
# Trying removal of: Bsmt Qual 981762980.5596
# Trying removal of: Bsmt Exposure 984572991.6119
# Trying removal of: Gr Liv Area 1304801185.1439
# Trying removal of: Bsmt Full Bath 1009352824.5549
# Trying removal of: Kitchen Qual 986164039.0314
# Trying removal of: Fireplaces 975222851.7198
# Trying removal of: Garage Cars 984325924.8688
# Trying removal of: Screen Porch 980576582.7212
#
# Removing Fireplaces:  CV score (MSE) 975222851.7198
#
# Round 60:
# Trying removal of: MS SubClass 1046911766.0774
# Trying removal of: Lot Area 992736423.1407
# Trying removal of: Overall Qual 1126829504.351
# Trying removal of: Overall Cond 1004720819.5131
# Trying removal of: Year Built 1008757603.7792
# Trying removal of: Mas Vnr Area 992928101.5705
# Trying removal of: Exter Qual 1000603285.4735
# Trying removal of: Bsmt Qual 990971309.6176
# Trying removal of: Bsmt Exposure 997850656.3681
# Trying removal of: Gr Liv Area 1374700296.4741
# Trying removal of: Bsmt Full Bath 1024555718.5493
# Trying removal of: Kitchen Qual 994701096.1468
# Trying removal of: Garage Cars 995509164.1269
# Trying removal of: Screen Porch 994454113.3069
#
# Removing Bsmt Qual:  CV score (MSE) 990971309.6176
#
# Round 61:
# Trying removal of: MS SubClass 1059176540.8238
# Trying removal of: Lot Area 1008223665.9584
# Trying removal of: Overall Qual 1161391978.982
# Trying removal of: Overall Cond 1016528662.6161
# Trying removal of: Year Built 1040303155.3969
# Trying removal of: Mas Vnr Area 1007035756.4914
# Trying removal of: Exter Qual 1028511104.8517
# Trying removal of: Bsmt Exposure 1018068178.7958
# Trying removal of: Gr Liv Area 1396022821.4423
# Trying removal of: Bsmt Full Bath 1043261787.3106
# Trying removal of: Kitchen Qual 1014155296.4048
# Trying removal of: Garage Cars 1015676387.9462
# Trying removal of: Screen Porch 1008827893.271
#
# Removing Mas Vnr Area:  CV score (MSE) 1007035756.4914
#
# Round 62:
# Trying removal of: MS SubClass 1078477759.6601
# Trying removal of: Lot Area 1024434383.9543
# Trying removal of: Overall Qual 1188918266.018
# Trying removal of: Overall Cond 1030487017.1231
# Trying removal of: Year Built 1058873260.1527
# Trying removal of: Exter Qual 1050944415.9407
# Trying removal of: Bsmt Exposure 1036719088.1967
# Trying removal of: Gr Liv Area 1463776543.3001
# Trying removal of: Bsmt Full Bath 1063055792.6207
# Trying removal of: Kitchen Qual 1028444790.7806
# Trying removal of: Garage Cars 1034668544.8098
# Trying removal of: Screen Porch 1026583353.6239
#
# Removing Lot Area:  CV score (MSE) 1024434383.9543
#
# Round 63:
# Trying removal of: MS SubClass 1114122669.334
# Trying removal of: Overall Qual 1195831671.0586
# Trying removal of: Overall Cond 1047032187.2352
# Trying removal of: Year Built 1073404832.6177
# Trying removal of: Exter Qual 1067844808.1792
# Trying removal of: Bsmt Exposure 1060643908.5384
# Trying removal of: Gr Liv Area 1537439325.3573
# Trying removal of: Bsmt Full Bath 1088295982.1157
# Trying removal of: Kitchen Qual 1043936878.2279
# Trying removal of: Garage Cars 1056060688.5622
# Trying removal of: Screen Porch 1043789910.8736
#
# Removing Screen Porch:  CV score (MSE) 1043789910.8736
#
# Round 64:
# Trying removal of: MS SubClass 1139136900.7054
# Trying removal of: Overall Qual 1217942284.0313
# Trying removal of: Overall Cond 1067088220.718
# Trying removal of: Year Built 1089354543.0729
# Trying removal of: Exter Qual 1085761511.2538
# Trying removal of: Bsmt Exposure 1080869733.2428
# Trying removal of: Gr Liv Area 1577779156.002
# Trying removal of: Bsmt Full Bath 1112256515.5413
# Trying removal of: Kitchen Qual 1063404754.6691
# Trying removal of: Garage Cars 1075877766.5374
#
# Removing Kitchen Qual:  CV score (MSE) 1063404754.6691
#
# Round 65:
# Trying removal of: MS SubClass 1163275914.9995
# Trying removal of: Overall Qual 1260959316.9151
# Trying removal of: Overall Cond 1090391758.9855
# Trying removal of: Year Built 1113740863.6179
# Trying removal of: Exter Qual 1153044197.0654
# Trying removal of: Bsmt Exposure 1101529048.2927
# Trying removal of: Gr Liv Area 1617378636.9636
# Trying removal of: Bsmt Full Bath 1135143229.4805
# Trying removal of: Garage Cars 1095355842.1248
#
# Removing Overall Cond:  CV score (MSE) 1090391758.9855
#
# Round 66:
# Trying removal of: MS SubClass 1195571417.9021
# Trying removal of: Overall Qual 1336666852.7381
# Trying removal of: Year Built 1120535508.0157
# Trying removal of: Exter Qual 1173458034.1635
# Trying removal of: Bsmt Exposure 1128866432.0342
# Trying removal of: Gr Liv Area 1621016263.9589
# Trying removal of: Bsmt Full Bath 1163857146.7507
# Trying removal of: Garage Cars 1120683457.3998
#
# Removing Year Built:  CV score (MSE) 1120535508.0157
#
# Round 67:
# Trying removal of: MS SubClass 1220300440.0342
# Trying removal of: Overall Qual 1463152531.9211
# Trying removal of: Exter Qual 1223707506.9066
# Trying removal of: Bsmt Exposure 1167852674.1367
# Trying removal of: Gr Liv Area 1618368912.8713
# Trying removal of: Bsmt Full Bath 1204332643.9438
# Trying removal of: Garage Cars 1178815156.9925
#
# Removing Bsmt Exposure:  CV score (MSE) 1167852674.1367
#
# Round 68:
# Trying removal of: MS SubClass 1255865114.123
# Trying removal of: Overall Qual 1549221476.7395
# Trying removal of: Exter Qual 1279113948.0961
# Trying removal of: Gr Liv Area 1635389197.9366
# Trying removal of: Bsmt Full Bath 1291595818.0957
# Trying removal of: Garage Cars 1238588018.3329
#
# Removing Garage Cars:  CV score (MSE) 1238588018.3329
#
# Round 69:
# Trying removal of: MS SubClass 1344997328.1377
# Trying removal of: Overall Qual 1799415973.9253
# Trying removal of: Exter Qual 1369154253.0346
# Trying removal of: Gr Liv Area 1824183352.6824
# Trying removal of: Bsmt Full Bath 1383936867.5862
#
# Removing MS SubClass:  CV score (MSE) 1344997328.1377
#
# Round 70:
# Trying removal of: Overall Qual 1896607585.2532
# Trying removal of: Exter Qual 1478111310.9377
# Trying removal of: Gr Liv Area 1900442721.9238
# Trying removal of: Bsmt Full Bath 1487932574.739
#
# Removing Exter Qual:  CV score (MSE) 1478111310.9377
#
# Round 71:
# Trying removal of: Overall Qual 2697222579.8098
# Trying removal of: Gr Liv Area 2064343485.4324
# Trying removal of: Bsmt Full Bath 1634711678.946
#
# Removing Bsmt Full Bath:  CV score (MSE) 1634711678.946
#
# Round 72:
# Trying removal of: Overall Qual 3056002970.5036
# Trying removal of: Gr Liv Area 2190446626.8455
#
# Removing Gr Liv Area:  CV score (MSE) 2190446626.8455
# Best Feature Subset (Backward Selection): ['MS SubClass', 'Lot Area', 'Street', 'Lot Shape', 'Land Contour', 'Land Slope', 'Neighborhood', 'Bldg Type', 'House Style', 'Overall Qual', 'Overall Cond', 'Year Built', 'Roof Style', 'Exterior 1st', 'Mas Vnr Area', 'Exter Qual', 'Exter Cond', 'Bsmt Qual', 'Bsmt Exposure', 'BsmtFin Type 1', 'Bsmt Unf SF', 'Heating QC', 'Low Qual Fin SF', 'Gr Liv Area', 'Bsmt Full Bath', 'Half Bath', 'Kitchen AbvGr', 'Kitchen Qual', 'Functional', 'Fireplaces', 'Garage Yr Blt', 'Garage Cars', 'Garage Qual', 'Garage Cond', 'Wood Deck SF', 'Enclosed Porch', 'Screen Porch', 'Yr Sold', 'Sale Condition']
# Best CV RMSE Score (Backward Selection): $30,190.24

# %% [markdown]
# ### Problem Two Graded Questions
#
# Assign `a2a` to the number of features in the best feature set found

# %%
# Your answer here; use an expression, not a constant derived by examining the data

a2a = len(best_feature_set_backward)                   # replace 0 with an expression

# %%
# Do not change this cell in any way

print(f"a2a = {a2a}")
# Out:
# a2a = 39

# %% [markdown]
# Assign `a2b` to the best CV RMSE score found.

# %%
# Your answer here; use an expression, not a constant derived by examining the data

a2b = np.sqrt(best_mse_score_backward)                     # replace 0 with an expression

# %%
# Do not change this cell in any way

print(f"a2b = ${a2b:,.2f}")
# Out:
# a2b = $30,190.24

# %% [markdown]
# ## **Problem Three: Ridge Regression on the Ames Housing Dataset**
#
# In this problem, we will apply Ridge Regression to the Ames Housing dataset. Ridge Regression includes a hyperparameter $\alpha$ that controls the strength of the regularization penalty, which helps prevent overfitting by constraining the growth of the model’s coefficients. A higher $\alpha$ penalizes large coefficients more, while a lower $\alpha$ allows them to grow larger.
#
# When creating the model, the parameter must be specified, for example:
#
# ```python
# ridge_model = Ridge(alpha=100)
# ```
#
# This introduces another instance of the model selection problem: we must determine the value of $\alpha$ that yields the best CV RMSE score.
#
# **Steps to Follow:**
#
# 1. **Standardize the Data:**
#    Ridge regression is sensitive to the scale of the features, so we will use `StandardScaler` to standardize the feature set to have a mean of 0 and a standard deviation of 1 before training and testing. Note that the target variable does **not** need to be scaled.
#
# 2. **Perform Cross-Validation Over a Range of Alpha Values:**
#    For each $\alpha \in \{100, 110, 120, \dots, 500\}$, calculate the cross-validation RMSE score for the model using 5-Fold CV scoring.
#
# 3. **Visualize the Results:**
#    Plot the CV RMSE scores against the $\alpha$ values.
#
# 4. **Identify the Best Alpha:**
#    Determine the $\alpha$ that results in the minimum CV RMSE Score and print it out, along with the score.
#
# **Tip:** It would be an *excellent* idea to add the suffix `_scaled` to any set to which you apply scaling.

# %%
# Your code here
# 1. Standardize the features (X_train only, not y_train)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)  # Keeps it as a NumPy array

# Optional: If you want to keep it as a DataFrame with column names
# X_train_scaled = pd.DataFrame(scaler.fit_transform(X_train), columns=X_train.columns)

# 2. Set up alpha values to test
alpha_values = np.arange(100, 501, 10)

# 3. Store RMSEs
cv_rmse_scores = []

# 4. Loop through alphas and compute 5-fold CV RMSE
for alpha in alpha_values:
    ridge_model = Ridge(alpha=alpha)
    mse = -cross_val_score(
        ridge_model, 
        X_train_scaled, 
        y_train, 
        scoring='neg_mean_squared_error', 
        cv=5
    ).mean()
    rmse = np.sqrt(mse)
    cv_rmse_scores.append(rmse)

# 5. Plot RMSE vs. alpha
plt.figure(figsize=(10, 6))
plt.plot(alpha_values, cv_rmse_scores, marker='o')
plt.xlabel("Alpha (Regularization Strength)")
plt.ylabel("CV RMSE ($)")
plt.title("Ridge Regression: CV RMSE vs. Alpha")
plt.grid(True)
plt.tight_layout()
plt.show()

# 6. Identify best alpha and score
best_index = np.argmin(cv_rmse_scores)
best_alpha = alpha_values[best_index]
best_rmse = cv_rmse_scores[best_index]

print(f"Best Alpha: {best_alpha}")
print(f"Best CV RMSE Score: ${best_rmse:,.2f}")
# Out:
# Best Alpha: 300
# Best CV RMSE Score: $31,154.32

# %% [markdown]
# ### Problem Three Graded Answers
#
# Set `a3a` to the alpha determined to have the minimum CV RMSE score.

# %%
# Your answer here; use an expression, not a constant derived by examining the data

a3a = best_alpha                  # replace 0 with an expression

# %%
# Do not change this cell in any way. 

print(f"a3a = {a3a}")
# Out:
# a3a = 300

# %% [markdown]
# Set `a3b` to the CV score found at that alpha.

# %%
# Your answer here; use an expression, not a constant derived by examining the data

a3b = best_rmse                  # replace 0 with an expression

# %%
# Do not change this cell in any way. 

print(f"a3b = ${a3b:,.2f}")
# Out:
# a3b = $31,154.32

# %% [markdown]
# ## **Problem Four: Evaluate Your Best Model**
#
# In this final problem, you will identify the model with the best cross-validation RMSE score and evaluate its performance on the held-out test set.
#
# #### **Steps to Follow:**
#
# 1. **Identify the Best Model:**
#    From your previous results, select the model that achieved the lowest CV RMSE score.
#
# 3. **Train and Test the Selected Model:**
#    - For Forward or Backward Feature Selection:  Train a Linear Regression model using `X_train` **restricted to the selected best feature set**, and evaluate it on `X_test` restricted to the same feature set.
#    - For Ridge Regression:   Train a Ridge Regression model using the best alpha found from cross-validation, with `StandardScaler` applied to both `X_train` and `X_test` before training and testing.
#
# 4. **Report Your Results:**
#    Print the name of the best model and the test RMSE in dollars.

# %%
# Your code here
cv_scores = {
    'Forward Selection': a1b,
    'Backward Selection': a2b,
    'Ridge Regression': a3b
}

# Identify best model
best_model_name = min(cv_scores, key=cv_scores.get)
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression, Ridge

if best_model_name == 'Forward Selection':
    model = LinearRegression()
    model.fit(X_train[best_feature_set], y_train)
    y_pred = model.predict(X_test[best_feature_set])
    
elif best_model_name == 'Backward Selection':
    model = LinearRegression()
    model.fit(X_train[best_feature_set_backward], y_train)
    y_pred = model.predict(X_test[best_feature_set_backward])

elif best_model_name == 'Ridge Regression':
    # Scale both train and test sets
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)
    
    model = Ridge(alpha=best_alpha)
    model.fit(X_train_scaled, y_train)
    y_pred = model.predict(X_test_scaled)

# Calculate test RMSE
test_rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print(f"Best Model: {best_model_name}")
print(f"Test RMSE: ${test_rmse:,.2f}")
# Out:
# Best Model: Backward Selection
# Test RMSE: $33,765.28

# %% [markdown]
# ### Problem Four Graded Answers
#
# Set `a4a` to the best model, according to the CV RMSE score.

# %%
# Your answer here

a4a = best_model_name                     # replace 0 with one of [1,2,3]

# %%
# Do not change this cell in any way. 

print(f"a4a = {a4a}")
# Out:
# a4a = Backward Selection

# %% [markdown]
# Set `a4b` to the test RMSE for the best model.

# %%
# Your answer here; use an expression, not a constant derived by examining the data

a4b = test_rmse                 # replace 0 with an expression

# %%
# Do not change this cell in any way. 

print(f"a4b = ${a4b:,.2f}")
# Out:
# a4b = $33,765.28

# %% [markdown]
# ### Final question...
#
# Why didn't we evaluate *all* the models on the test set and compare them?
#
# ### Some answers...
#
# It’s tempting to reconsider your choice based on test scores, but this violates the core principle of not "training to the test." That’s why we deliberately avoided evaluating all models on the test set.
#
# The test set doesn’t influence model training; it serves as a final, unbiased check on how well your chosen model generalizes to unseen data, ensuring that your selection process wasn’t overly optimistic.
#
# A natural **next question** is: Why use a test set at all? Beyond being an industry-standard practice that simulates the real world—where you can’t adjust your model after deployment—consider:
#
# - **Validating your workflow:** A strong test score confirms that your model selection process (feature selection, hyperparameter tuning, etc.) was sound. A poor test score despite good cross-validation results may indicate overfitting or a flawed approach.
#
# - **Guarding against over-optimism:** Cross-validation can be slightly optimistic, especially with limited data or repeated trials. The test set provides a final safeguard against relying on an overly tuned model.
